# %%
import pyomo.environ as pyo
from pyomo.opt import SolverFactory, TerminationCondition
import psycopg2

# %%
conexion = psycopg2.connect(
        dbname="buap",
        user="postgres",
        password="contrasena",
        host="localhost",
        port="5432"
    )
cursor = conexion.cursor()
datos = {}

# %%
# Profesores (con nombre)
cursor.execute("SELECT id_profesor, nombre, id_contrato FROM Profesor  ")
profesores = cursor.fetchall()
datos['Id_Profesores'] = [row[0] for row in profesores] # Lista de IDs de profesores
datos['nombres_profesor'] = {row[0]: row[1] for row in profesores} # Diccionario de nombres de profesores
datos['Tipo_Contrato'] = {row[0]: row[2] for row in profesores} # Diccionario de tipo de contrato de cada profesor

# %%
#TIpos de contratos 
cursor.execute("SELECT id_contrato, horas_minimas, horas_maximas FROM Contrato WHERE id_contrato = ANY(%s)", (list(datos['Tipo_Contrato'].values()),))
contratos_detalles = cursor.fetchall()
datos['Detalles_Contratos'] = {row[0]: {'min': row[1], 'max': row[2]} for row in contratos_detalles}  # Detalles por id_contrato
datos['Detalles_Contratos'][4] = {'min': 0, 'max': 99}  # Contrato de profesor imaginario

# %%
# Materias (con nombre)
cursor.execute("SELECT id_materia, nombre, horas_por_semana, id_tipo_clase, id_programa_educativo FROM Materia limit 10")
materias = cursor.fetchall()
datos['id_Materias'] = [row[0] for row in materias] # Lista de IDs de materias
datos['nombres_materia'] = {row[0]: row[1] for row in materias} # Diccionario de nombres de materias
datos['Horas_Semana_Materia'] = {row[0]: row[2] for row in materias} # Diccionario de horas por semana de cada materia
datos['Tipo_Clase'] = {row[0]: row[3] for row in materias} # Diccionario de tipo de clase de cada materia
datos['Programa_Educativo_Materia'] = {row[0]: row[4] for row in materias} # Diccionario de programa educativo de cada materia

# %%
# Aulas
cursor.execute("SELECT id_aula, id_edificio, id_tipo_clase FROM Aula ")
rows = cursor.fetchall()

datos['Aulas'] = [(row[0], row[1]) for row in rows] # Lista de IDs compuestos (id_aula, id_edificio)
datos['Tipo_Aula'] = {(row[0], row[1]): row[2] for row in rows}# Diccionario: clave compuesta (id_aula, id_edificio) -> tipo clase

# Edificios 
cursor.execute("SELECT id_edificio, nombre FROM Edificio")
rows = cursor.fetchall()

datos['Id_Edificios'] = [row[0] for row in rows]          # Lista con todos los id_edificio
datos['Edificios'] = {row[0]: row[1] for row in rows}     # Diccionario id_edificio -> nombre



# Bloques horarios
datos['Dia'] = list(range(1, 6)) # Lunes a Viernes
datos['Hora'] = list(range(1, 11)) # 10 bloques horarios por día/ de 8 am a 6 pm

# %%
# Programa Educativo
cursor.execute("SELECT id_programa_educativo, nombre, abreviatura, id_unidad_academica FROM Programa_Educativo")
rows = cursor.fetchall()

# Lista de IDs
datos['Id_Programas_Educativos'] = [row[0] for row in rows]

# Diccionario completo: id_programa_educativo -> (nombre, abreviatura, id_unidad_academica)
datos['Programas_Educativos'] = {
    row[0]: {
        'nombre': row[1],
        'abreviatura': row[2],
        'id_unidad_academica': row[3]
    }
    for row in rows
}

# También puedes guardar por separado si lo necesitas
datos['Nombre_Programa'] = {row[0]: row[1] for row in rows}
datos['Abreviatura_Programa'] = {row[0]: row[2] for row in rows}
datos['Unidad_Academica_Programa'] = {row[0]: row[3] for row in rows}

# %%
aulas_param = datos['Aulas']  # lista de tuplas (id_aula, id_edificio)

query = """
SELECT A.id_aula, A.id_edificio, M.id_materia,
       CASE WHEN A.id_tipo_clase = M.id_tipo_clase THEN 1 ELSE 0 END AS compatible,
       M.id_tipo_clase AS tipo_materia,
       A.id_tipo_clase AS tipo_aula
FROM Aula A
CROSS JOIN Materia M
WHERE (A.id_aula, A.id_edificio) = ANY(%s) AND M.id_materia = ANY(%s)
"""

cursor.execute(query, (aulas_param, datos['id_Materias']))

datos['Compatibiliadad_Aula_Materia'] = {
    ((row[0], row[1]), row[2]): {
        'compatible': row[3],
        'tipo_materia': row[4],
        'tipo_aula': row[5]
    }
    for row in cursor.fetchall()
}

# %%
from collections import defaultdict
import unicodedata
import re

def normalizar_nombre(nombre):
    nombre = nombre.lower()
    nombre = ''.join(
        c for c in unicodedata.normalize('NFD', nombre)
        if unicodedata.category(c) != 'Mn'
    )
    nombre = nombre.strip()
    nombre = re.sub(r'\s+', ' ', nombre)
    return nombre

datos['Materias_por_Profesor'] = defaultdict(list)
datos['Profesores_por_Materia'] = defaultdict(list)
datos['Profesores_Imaginarios'] = []
datos['Profesores_Totales'] = []

# Crear dict normalizado nombre -> lista ids materias
materias_por_nombre = defaultdict(list)
for mid in datos['id_Materias']:
    nombre_original = datos['nombres_materia'][mid]
    nombre_norm = normalizar_nombre(nombre_original)
    materias_por_nombre[nombre_norm].append(mid)

cursor.execute("""
    SELECT id_profesor, id_materia 
    FROM profesor_materia
    WHERE id_profesor = ANY(%s) AND id_materia = ANY(%s)
""", (datos['Id_Profesores'], datos['id_Materias']))

for profe_id, materia_id in cursor.fetchall():
    nombre_original = datos['nombres_materia'][materia_id]
    nombre_norm = normalizar_nombre(nombre_original)
    materias_similares = materias_por_nombre[nombre_norm]
    for mid in materias_similares:
        if mid not in datos['Materias_por_Profesor'][profe_id]:
            datos['Materias_por_Profesor'][profe_id].append(mid)
        if profe_id not in datos['Profesores_por_Materia'][mid]:
            datos['Profesores_por_Materia'][mid].append(profe_id)

materias_sin_profesor = [m for m in datos['id_Materias'] if m not in datos['Profesores_por_Materia']]

profesores_imaginarios = [f"PA_{i}" for i in range(len(materias_sin_profesor))]
datos['Profesores_Imaginarios'] = profesores_imaginarios
print("Se han creado", len(profesores_imaginarios), "profesores imaginarios para las materias sin profesor asignado.")

for i, materia_id in enumerate(materias_sin_profesor):
    profe_imag = profesores_imaginarios[i]
    datos['Profesores_por_Materia'][materia_id].append(profe_imag)
    datos['Materias_por_Profesor'][profe_imag].append(materia_id)
    datos['Tipo_Contrato'][profe_imag] = 4

datos['Profesores_Totales'].extend(datos['Id_Profesores'])
datos['Profesores_Totales'].extend(profesores_imaginarios)

datos['nombres_profesor'].update({
    p: f"ProfFicticio_{i}" for i, p in enumerate(profesores_imaginarios)
})
# Out:
# Se han creado 0 profesores imaginarios para las materias sin profesor asignado.

# %%
import pandas as pd

def leer_bloques_desde_excel(ruta_archivo):
    # Leer archivo CSV
    df = pd.read_csv(ruta_archivo)

    print("Columnas en el archivo:", df.columns.tolist())

    bloques = {}

    for _, fila in df.iterrows():
        programa = fila['Programa']
        materia = fila['Materia']
        bloque = fila['Bloque']
        cupo = fila['Cupo']

        if bloque not in bloques:
            bloques[bloque] = {
                'programa_educativo': programa,
                'materias': [],
                'cupo': cupo
            }
        bloques[bloque]['materias'].append(materia)

    return bloques

ruta = r"C:\Users\bdgae\Desktop\Nueva carpeta\exportado.csv"
datos['Bloques'] = leer_bloques_desde_excel(ruta)
# Out:
# Columnas en el archivo: ['Programa', 'Materia', 'Bloque', 'Cupo']

# %%
def reemplazar_materias_por_id_en_bloques(bloques, datos):
    # Crear un dict normalizado nombre + programa -> lista de ids
    materias_por_nombre_programa = defaultdict(list)
    
    for mid in datos['id_Materias']:
        nombre_original = datos['nombres_materia'][mid]
        programa_id = datos['Programa_Educativo_Materia'][mid]
        # Normalizar nombre de materia
        nombre_norm = normalizar_nombre(nombre_original)
        materias_por_nombre_programa[(nombre_norm, programa_id)].append(mid)
    
    bloques_con_ids = {}
    for bloque, info in bloques.items():
        programa_nombre = info['programa_educativo']
        
        # Obtener id del programa educativo basado en la abreviatura o nombre
        programa_id = None
        for pid, pinfo in datos['Programas_Educativos'].items():
            # Puedes comparar por abreviatura o nombre, ajusta según tus datos
            if 'abreviatura' in pinfo and pinfo['abreviatura'] == programa_nombre:
                programa_id = pid
                break
            elif 'nombre' in pinfo and pinfo['nombre'] == programa_nombre:
                programa_id = pid
                break
        
        if programa_id is None:
            print(f"Programa educativo '{programa_nombre}' no encontrado en datos.")
            continue
        
        materias_ids = []
        for materia_nombre in info['materias']:
            materia_norm = normalizar_nombre(materia_nombre)
            posibles_ids = materias_por_nombre_programa.get((materia_norm, programa_id), [])
            if posibles_ids:
                # Si hay más de uno, toma el primero (o ajusta si quieres otro criterio)
                materias_ids.append(posibles_ids[0])
            else:
                # Materia no encontrada o no corresponde al programa
                print(f"Materia '{materia_nombre}' no encontrada para programa '{programa_nombre}', se omitirá.")
        
        bloques_con_ids[bloque] = {
            'programa_educativo': programa_nombre,
            'materias': materias_ids,
            'cupo': info['cupo']
        }
    
    return bloques_con_ids

# Uso
datos['Bloques'] = reemplazar_materias_por_id_en_bloques(datos['Bloques'], datos)
# Out:
# Materia 'Introducción a la FGU' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Arquitectura de la Antigüedad' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Métodos y Estrat. Proyectuales' no encontrada para programa 'ARQ', se omitirá.
# Materia 'P. Inclusión Soc.en el Espacio' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Taller de Diseño Integral I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Matem. Aplicadas a la Arqui.II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducc. a las Instalaciones' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Conc. Básicos de Construcción' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Arquitectura de la Antigüedad' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Métodos y Estrat. Proyectuales' no encontrada para programa 'ARQ', se omitirá.
# Materia 'P. Inclusión Soc.en el Espacio' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Taller de Diseño Integral I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Matem. Aplicadas a la Arqui.II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducc. a las Instalaciones' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Conc. Básicos de Construcción' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Arquitectura de la Antigüedad' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Métodos y Estrat. Proyectuales' no encontrada para programa 'ARQ', se omitirá.
# Materia 'P. Inclusión Soc.en el Espacio' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Taller de Diseño Integral I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Matem. Aplicadas a la Arqui.II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducc. a las Instalaciones' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Conc. Básicos de Construcción' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Arquitectura de la Antigüedad' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Métodos y Estrat. Proyectuales' no encontrada para programa 'ARQ', se omitirá.
# Materia 'P. Inclusión Soc.en el Espacio' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Taller de Diseño Integral I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Matem. Aplicadas a la Arqui.II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducc. a las Instalaciones' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Conc. Básicos de Construcción' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Arquitectura de la Antigüedad' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Métodos y Estrat. Proyectuales' no encontrada para programa 'ARQ', se omitirá.
# Materia 'P. Inclusión Soc.en el Espacio' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Taller de Diseño Integral I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Matem. Aplicadas a la Arqui.II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducc. a las Instalaciones' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Conc. Básicos de Construcción' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Arquitectura de la Antigüedad' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Métodos y Estrat. Proyectuales' no encontrada para programa 'ARQ', se omitirá.
# Materia 'P. Inclusión Soc.en el Espacio' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Taller de Diseño Integral I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Matem. Aplicadas a la Arqui.II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducc. a las Instalaciones' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Conc. Básicos de Construcción' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Arquitectura de la Antigüedad' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Métodos y Estrat. Proyectuales' no encontrada para programa 'ARQ', se omitirá.
# Materia 'P. Inclusión Soc.en el Espacio' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Taller de Diseño Integral I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Matem. Aplicadas a la Arqui.II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducc. a las Instalaciones' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Conc. Básicos de Construcción' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Arquitectura de la Antigüedad' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Métodos y Estrat. Proyectuales' no encontrada para programa 'ARQ', se omitirá.
# Materia 'P. Inclusión Soc.en el Espacio' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Taller de Diseño Integral I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Matem. Aplicadas a la Arqui.II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducc. a las Instalaciones' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Conc. Básicos de Construcción' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Arquitectura de la Antigüedad' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Métodos y Estrat. Proyectuales' no encontrada para programa 'ARQ', se omitirá.
# Materia 'P. Inclusión Soc.en el Espacio' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Taller de Diseño Integral I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Matem. Aplicadas a la Arqui.II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducc. a las Instalaciones' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Conc. Básicos de Construcción' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Arquitectura de la Antigüedad' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Métodos y Estrat. Proyectuales' no encontrada para programa 'ARQ', se omitirá.
# Materia 'P. Inclusión Soc.en el Espacio' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Taller de Diseño Integral I' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Matem. Aplicadas a la Arqui.II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Introducc. a las Instalaciones' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Conc. Básicos de Construcción' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ARQ', se omitirá.
# Materia 'Fisicoquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'DHPC' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biomatematicas II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Bioquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'Estructura y Funcion Celular' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biologia. de Org. Unicelulares' no encontrada para programa 'BIO', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Fisicoquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'DHPC' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biomatematicas II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Bioquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'Estructura y Funcion Celular' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biologia. de Org. Unicelulares' no encontrada para programa 'BIO', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Fisicoquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'DHPC' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biomatematicas II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Bioquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'Estructura y Funcion Celular' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biologia. de Org. Unicelulares' no encontrada para programa 'BIO', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Fisicoquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'DHPC' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biomatematicas II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Bioquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'Estructura y Funcion Celular' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biologia. de Org. Unicelulares' no encontrada para programa 'BIO', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Fisicoquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'DHPC' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biomatematicas II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Bioquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'Estructura y Funcion Celular' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biologia. de Org. Unicelulares' no encontrada para programa 'BIO', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Fisicoquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'DHPC' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biomatematicas II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Bioquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'Estructura y Funcion Celular' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biologia. de Org. Unicelulares' no encontrada para programa 'BIO', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Fisicoquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'DHPC' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biomatematicas II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Bioquimica' no encontrada para programa 'BIO', se omitirá.
# Materia 'Estructura y Funcion Celular' no encontrada para programa 'BIO', se omitirá.
# Materia 'Biologia. de Org. Unicelulares' no encontrada para programa 'BIO', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'BIO', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'BIO', se omitirá.
# Materia 'Matemáticas para la Comput. I' no encontrada para programa 'CCO', se omitirá.
# Materia 'Álgebra Superior' no encontrada para programa 'CCO', se omitirá.
# Materia 'Ensamblador' no encontrada para programa 'CCO', se omitirá.
# Materia 'Programación Estructurada' no encontrada para programa 'CCO', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'CCO', se omitirá.
# Materia 'Matemáticas para la Comp. II' no encontrada para programa 'CCO', se omitirá.
# Materia 'Programación Orientada a Obj.' no encontrada para programa 'CCO', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'CCO', se omitirá.
# Materia 'Matemáticas Discretas y Aplic.' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'CCO', se omitirá.
# Materia 'Matemáticas para la Comput. I' no encontrada para programa 'CCO', se omitirá.
# Materia 'Álgebra Superior' no encontrada para programa 'CCO', se omitirá.
# Materia 'Ensamblador' no encontrada para programa 'CCO', se omitirá.
# Materia 'Programación Estructurada' no encontrada para programa 'CCO', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'CCO', se omitirá.
# Materia 'Matemáticas para la Comp. II' no encontrada para programa 'CCO', se omitirá.
# Materia 'Programación Orientada a Obj.' no encontrada para programa 'CCO', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'CCO', se omitirá.
# Materia 'Matemáticas Discretas y Aplic.' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'CCO', se omitirá.
# Materia 'Matemáticas para la Comput. I' no encontrada para programa 'CCO', se omitirá.
# Materia 'Álgebra Superior' no encontrada para programa 'CCO', se omitirá.
# Materia 'Ensamblador' no encontrada para programa 'CCO', se omitirá.
# Materia 'Programación Estructurada' no encontrada para programa 'CCO', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'CCO', se omitirá.
# Materia 'Matemáticas para la Comp. II' no encontrada para programa 'CCO', se omitirá.
# Materia 'Programación Orientada a Obj.' no encontrada para programa 'CCO', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'CCO', se omitirá.
# Materia 'Matemáticas Discretas y Aplic.' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'CCO', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'CCO', se omitirá.
# Materia 'Matemáticas para el Diseño' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo e Ilust. Digital Vector' no encontrada para programa 'DSG', se omitirá.
# Materia 'Procesos de Diseño' no encontrada para programa 'DSG', se omitirá.
# Materia 'Expresión Comunicativa' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Color' no encontrada para programa 'DSG', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'DSG', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Taller de Diseño Básico' no encontrada para programa 'DSG', se omitirá.
# Materia 'Fotografía I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Edición Digital de Imagen' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'DSG', se omitirá.
# Materia 'Tipografía I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Comunicación Visual I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Hist. Arte y Diseño Gráfico I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'DSG', se omitirá.
# Materia 'Taller de Diseño Gráfico I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Matemáticas para el Diseño' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo e Ilust. Digital Vector' no encontrada para programa 'DSG', se omitirá.
# Materia 'Procesos de Diseño' no encontrada para programa 'DSG', se omitirá.
# Materia 'Expresión Comunicativa' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Color' no encontrada para programa 'DSG', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'DSG', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Taller de Diseño Básico' no encontrada para programa 'DSG', se omitirá.
# Materia 'Fotografía I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Edición Digital de Imagen' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'DSG', se omitirá.
# Materia 'Tipografía I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Comunicación Visual I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Hist. Arte y Diseño Gráfico I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'DSG', se omitirá.
# Materia 'Taller de Diseño Gráfico I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Matemáticas para el Diseño' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo e Ilust. Digital Vector' no encontrada para programa 'DSG', se omitirá.
# Materia 'Procesos de Diseño' no encontrada para programa 'DSG', se omitirá.
# Materia 'Expresión Comunicativa' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Color' no encontrada para programa 'DSG', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'DSG', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Taller de Diseño Básico' no encontrada para programa 'DSG', se omitirá.
# Materia 'Fotografía I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Edición Digital de Imagen' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'DSG', se omitirá.
# Materia 'Tipografía I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Comunicación Visual I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Hist. Arte y Diseño Gráfico I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'DSG', se omitirá.
# Materia 'Taller de Diseño Gráfico I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Matemáticas para el Diseño' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo e Ilust. Digital Vector' no encontrada para programa 'DSG', se omitirá.
# Materia 'Procesos de Diseño' no encontrada para programa 'DSG', se omitirá.
# Materia 'Expresión Comunicativa' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Color' no encontrada para programa 'DSG', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'DSG', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Taller de Diseño Básico' no encontrada para programa 'DSG', se omitirá.
# Materia 'Fotografía I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Edición Digital de Imagen' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'DSG', se omitirá.
# Materia 'Tipografía I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Comunicación Visual I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Hist. Arte y Diseño Gráfico I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'DSG', se omitirá.
# Materia 'Taller de Diseño Gráfico I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Matemáticas para el Diseño' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo e Ilust. Digital Vector' no encontrada para programa 'DSG', se omitirá.
# Materia 'Procesos de Diseño' no encontrada para programa 'DSG', se omitirá.
# Materia 'Expresión Comunicativa' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Color' no encontrada para programa 'DSG', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'DSG', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Taller de Diseño Básico' no encontrada para programa 'DSG', se omitirá.
# Materia 'Fotografía I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Edición Digital de Imagen' no encontrada para programa 'DSG', se omitirá.
# Materia 'Dibujo II' no encontrada para programa 'DSG', se omitirá.
# Materia 'Tipografía I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Comunicación Visual I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Hist. Arte y Diseño Gráfico I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'DSG', se omitirá.
# Materia 'Taller de Diseño Gráfico I' no encontrada para programa 'DSG', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Introduccion a la Farmacia' no encontrada para programa 'FAR', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'FAR', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'FAR', se omitirá.
# Materia 'DHPC' no encontrada para programa 'FAR', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'FAR', se omitirá.
# Materia 'Fisica' no encontrada para programa 'FAR', se omitirá.
# Materia 'Fisica(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Seguridad en el Laboratorio' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Organica I' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Organica I(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'FAR', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Bioetica y Deontologia Farmac' no encontrada para programa 'FAR', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'FAR', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Introduccion a la Farmacia' no encontrada para programa 'FAR', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'FAR', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'FAR', se omitirá.
# Materia 'DHPC' no encontrada para programa 'FAR', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'FAR', se omitirá.
# Materia 'Fisica' no encontrada para programa 'FAR', se omitirá.
# Materia 'Fisica(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Seguridad en el Laboratorio' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Organica I' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Organica I(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'FAR', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Bioetica y Deontologia Farmac' no encontrada para programa 'FAR', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'FAR', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Introduccion a la Farmacia' no encontrada para programa 'FAR', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'FAR', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'FAR', se omitirá.
# Materia 'DHPC' no encontrada para programa 'FAR', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'FAR', se omitirá.
# Materia 'Fisica' no encontrada para programa 'FAR', se omitirá.
# Materia 'Fisica(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Seguridad en el Laboratorio' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Organica I' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Organica I(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'FAR', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'FAR', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'FAR', se omitirá.
# Materia 'Bioetica y Deontologia Farmac' no encontrada para programa 'FAR', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'FAR', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICC', se omitirá.
# Materia 'Ingeniería Social' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICC', se omitirá.
# Materia 'Física' no encontrada para programa 'ICC', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICD', se omitirá.
# Materia 'Intro. a la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICD', se omitirá.
# Materia 'Ética para la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICC', se omitirá.
# Materia 'Ingeniería Social' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICC', se omitirá.
# Materia 'Física' no encontrada para programa 'ICC', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICD', se omitirá.
# Materia 'Intro. a la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICD', se omitirá.
# Materia 'Ética para la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICC', se omitirá.
# Materia 'Ingeniería Social' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICC', se omitirá.
# Materia 'Física' no encontrada para programa 'ICC', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICD', se omitirá.
# Materia 'Intro. a la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICD', se omitirá.
# Materia 'Ética para la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICC', se omitirá.
# Materia 'Ingeniería Social' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICC', se omitirá.
# Materia 'Física' no encontrada para programa 'ICC', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICD', se omitirá.
# Materia 'Intro. a la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICD', se omitirá.
# Materia 'Ética para la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICC', se omitirá.
# Materia 'Ingeniería Social' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICC', se omitirá.
# Materia 'Física' no encontrada para programa 'ICC', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICD', se omitirá.
# Materia 'Intro. a la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICD', se omitirá.
# Materia 'Ética para la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICC', se omitirá.
# Materia 'Ingeniería Social' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICC', se omitirá.
# Materia 'Física' no encontrada para programa 'ICC', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICD', se omitirá.
# Materia 'Intro. a la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICD', se omitirá.
# Materia 'Ética para la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICC', se omitirá.
# Materia 'Ingeniería Social' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICC', se omitirá.
# Materia 'Física' no encontrada para programa 'ICC', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICD', se omitirá.
# Materia 'Intro. a la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICD', se omitirá.
# Materia 'Ética para la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICC', se omitirá.
# Materia 'Ingeniería Social' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICC', se omitirá.
# Materia 'Física' no encontrada para programa 'ICC', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICD', se omitirá.
# Materia 'Intro. a la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICD', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICD', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICD', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICD', se omitirá.
# Materia 'Ética para la Ciencia de Datos' no encontrada para programa 'ICD', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICC', se omitirá.
# Materia 'Ingeniería Social' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICC', se omitirá.
# Materia 'Física' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a las Matemáticas' no encontrada para programa 'ITI', se omitirá.
# Materia 'Introducción a la Programación' no encontrada para programa 'ITI', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ITI', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ITI', se omitirá.
# Materia 'Análisis y Diseño de Software' no encontrada para programa 'ITI', se omitirá.
# Materia 'Gobernanza de Seguridad Info.' no encontrada para programa 'ITI', se omitirá.
# Materia 'Cálculo Superior' no encontrada para programa 'ITI', se omitirá.
# Materia 'Matemáticas Discretas y Aplic.' no encontrada para programa 'ITI', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ITI', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ITI', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ITI', se omitirá.
# Materia 'Programación Orientada a Objet' no encontrada para programa 'ITI', se omitirá.
# Materia 'Modelado Procesos de Negocio' no encontrada para programa 'ITI', se omitirá.
# Materia 'Fundamentos de Matemáticas' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Superior Aplicada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Básica' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ICC', se omitirá.
# Materia 'Ingeniería Social' no encontrada para programa 'ICC', se omitirá.
# Materia 'Álgebra Lineal con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Cálculo Diferencial con Aplic.' no encontrada para programa 'ICC', se omitirá.
# Materia 'Programación Avanzada' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ICC', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ICC', se omitirá.
# Materia 'Física' no encontrada para programa 'ICC', se omitirá.
# Materia 'Introducción a las Matemáticas' no encontrada para programa 'ITI', se omitirá.
# Materia 'Introducción a la Programación' no encontrada para programa 'ITI', se omitirá.
# Materia 'Introducción a la FGU' no encontrada para programa 'ITI', se omitirá.
# Materia 'Inglés I' no encontrada para programa 'ITI', se omitirá.
# Materia 'Análisis y Diseño de Software' no encontrada para programa 'ITI', se omitirá.
# Materia 'Gobernanza de Seguridad Info.' no encontrada para programa 'ITI', se omitirá.
# Materia 'Cálculo Superior' no encontrada para programa 'ITI', se omitirá.
# Materia 'Matemáticas Discretas y Aplic.' no encontrada para programa 'ITI', se omitirá.
# Materia 'Inglés II' no encontrada para programa 'ITI', se omitirá.
# Materia 'Inglés III' no encontrada para programa 'ITI', se omitirá.
# Materia 'Inglés IV' no encontrada para programa 'ITI', se omitirá.
# ...
# Materia 'Quimica General II(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Bioetica de la Invest.en Seres' no encontrada para programa 'QFB', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'QFB', se omitirá.
# Materia 'DHPC' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Seguridad en Laboratorios' no encontrada para programa 'QFB', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Bioetica de la Invest.en Seres' no encontrada para programa 'QFB', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'QFB', se omitirá.
# Materia 'DHPC' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Seguridad en Laboratorios' no encontrada para programa 'QFB', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Bioetica de la Invest.en Seres' no encontrada para programa 'QFB', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'QFB', se omitirá.
# Materia 'DHPC' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Seguridad en Laboratorios' no encontrada para programa 'QFB', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Bioetica de la Invest.en Seres' no encontrada para programa 'QFB', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'QFB', se omitirá.
# Materia 'DHPC' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Seguridad en Laboratorios' no encontrada para programa 'QFB', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Bioetica de la Invest.en Seres' no encontrada para programa 'QFB', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'QFB', se omitirá.
# Materia 'DHPC' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Seguridad en Laboratorios' no encontrada para programa 'QFB', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Bioetica de la Invest.en Seres' no encontrada para programa 'QFB', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'QFB', se omitirá.
# Materia 'DHPC' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Seguridad en Laboratorios' no encontrada para programa 'QFB', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Bioetica de la Invest.en Seres' no encontrada para programa 'QFB', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'QFB', se omitirá.
# Materia 'DHPC' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Seguridad en Laboratorios' no encontrada para programa 'QFB', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'QFB', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Calculo II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica' no encontrada para programa 'QFB', se omitirá.
# Materia 'Quimica Analitica Basica(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I' no encontrada para programa 'QFB', se omitirá.
# Materia 'Fisicoquimica I(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula' no encontrada para programa 'QFB', se omitirá.
# Materia 'Biol. Molec. de la Celula(LAB)' no encontrada para programa 'QFB', se omitirá.
# Materia 'Bioetica de la Invest.en Seres' no encontrada para programa 'QFB', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'QUI', se omitirá.
# Materia 'DHPC' no encontrada para programa 'QUI', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'QUI', se omitirá.
# Materia 'Calculo I' no encontrada para programa 'QUI', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'QUI', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'QUI', se omitirá.
# Materia 'Calculo II' no encontrada para programa 'QUI', se omitirá.
# Materia 'Fisica I' no encontrada para programa 'QUI', se omitirá.
# Materia 'Fisica I(LAB)' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'QUI', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica Analitica I' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica Analitica I(LAB)' no encontrada para programa 'QUI', se omitirá.
# Materia 'Formacion Humana y Social' no encontrada para programa 'QUI', se omitirá.
# Materia 'DHPC' no encontrada para programa 'QUI', se omitirá.
# Materia 'Lengua Extranjera I' no encontrada para programa 'QUI', se omitirá.
# Materia 'Calculo I' no encontrada para programa 'QUI', se omitirá.
# Materia 'Matematicas' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica General I' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica General I (LAB)' no encontrada para programa 'QUI', se omitirá.
# Materia 'Lengua Extranjera II' no encontrada para programa 'QUI', se omitirá.
# Materia 'Calculo II' no encontrada para programa 'QUI', se omitirá.
# Materia 'Fisica I' no encontrada para programa 'QUI', se omitirá.
# Materia 'Fisica I(LAB)' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica General II' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica General II(LAB)' no encontrada para programa 'QUI', se omitirá.
# Materia 'Herramientas Computacionales' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica Analitica I' no encontrada para programa 'QUI', se omitirá.
# Materia 'Quimica Analitica I(LAB)' no encontrada para programa 'QUI', se omitirá.

# %%
# Imprimir todas las claves (columnas) del diccionario 'datos' y el primer elemento de cada una (si aplica)
print("Columnas (claves) en 'datos':")
for key in datos.keys():
    print(f"{key}: ", end="")
    valor = datos[key]
    # Si es lista y no está vacía, imprime el primer elemento
    if isinstance(valor, list) and len(valor) > 0:
        print(valor[0])
    # Si es dict y no está vacío, imprime el primer par clave-valor
    elif isinstance(valor, dict) and len(valor) > 0:
        primera_clave = next(iter(valor))
        print(f"{primera_clave}: {valor[primera_clave]}")
    # Si es defaultdict y no está vacío, imprime el primer par clave-valor
    elif "defaultdict" in str(type(valor)) and len(valor) > 0:
        primera_clave = next(iter(valor))
        print(f"{primera_clave}: {valor[primera_clave]}")
    else:
        print(valor)
# Out:
# Columnas (claves) en 'datos':
# Id_Profesores: 100002999
# nombres_profesor: 100002999: GARCIA - ZENTENO EDUARDO
# Tipo_Contrato: 100002999: 3
# Detalles_Contratos: 1: {'min': 12, 'max': 20}
# id_Materias: 1
# nombres_materia: 1: Teoría de la Arquitectura
# Horas_Semana_Materia: 1: 3
# Tipo_Clase: 1: 4
# Programa_Educativo_Materia: 1: 5
# Aulas: (101, 2)
# Tipo_Aula: (101, 2): 3
# Id_Edificios: 1
# Edificios: 1: EMA1
# Dia: 1
# Hora: 1
# Id_Programas_Educativos: 1
# Programas_Educativos: 1: {'nombre': 'Licenciatura en Biología', 'abreviatura': 'BIO', 'id_unidad_academica': 1}
# Nombre_Programa: 1: Licenciatura en Biología
# Abreviatura_Programa: 1: BIO
# Unidad_Academica_Programa: 1: 1
# Compatibiliadad_Aula_Materia: ((101, 2), 1): {'compatible': 0, 'tipo_materia': 4, 'tipo_aula': 3}
# Materias_por_Profesor: 100004288: [1, 2, 3]
# Profesores_por_Materia: 1: [100004288, 100020344, 100502922, 100518251, 100528894, 100529762, 100538141]
# Profesores_Imaginarios: []
# Profesores_Totales: 100002999
# Bloques: ARQBLO1: {'programa_educativo': 'ARQ', 'materias': [1, 2, 3, 4, 5, 6, 7], 'cupo': 50}

# %%
# Definir los conjuntos
model = pyo.ConcreteModel()

# Conjuntos

materias_bloque_expandidas = []

for bloque, info in datos['Bloques'].items():
    for materia in info['materias']:
        materias_bloque_expandidas.append((bloque, materia))


model.Profesores = pyo.Set(initialize=datos['Profesores_Totales'])
model.MateriasPorBloqueExpandido = pyo.Set(initialize=materias_bloque_expandidas, dimen=2)
model.Materias = pyo.Set(initialize=sorted(set(m for _, m in materias_bloque_expandidas)))
model.Aulas = pyo.Set(dimen=2, initialize=[(aula_id, edificio_id) for aula_id, edificio_id in datos['Aulas']])
model.BloquesHorarios = pyo.Set(dimen=2, initialize=[(dia, hora) for dia in datos['Dia'] for hora in datos['Hora']])
model.Dias = pyo.Set(initialize=datos['Dia'])
model.Hora = pyo.Set(initialize=datos['Hora'])



bloques_con_materias = {bloque: info for bloque, info in datos['Bloques'].items() if info.get('materias')}

# Conjunto de bloques válidos
model.Bloques = pyo.Set(initialize=bloques_con_materias.keys())

# Conjunto MateriasPorBloque (solo para bloques con materias)
model.MateriasPorBloque = pyo.Set(
    model.Bloques,
    initialize={
        bloque: sorted(info['materias']) for bloque, info in bloques_con_materias.items()
    }
)

# %%
# Parámetros

model.Horas_Semana_Materia = pyo.Param(
    model.MateriasPorBloqueExpandido,
    initialize={(bloque, m): datos['Horas_Semana_Materia'][m] for (bloque, m) in materias_bloque_expandidas}
)
model.Tipo_Clase = pyo.Param(model.Materias, initialize=datos['Tipo_Clase'])
model.Tipo_Aula = pyo.Param(model.Aulas, initialize=datos['Tipo_Aula'])
model.Compatibilidad_Aula_Materia = pyo.Param(model.Aulas, model.Materias, initialize={
    (aula, materia): datos['Compatibiliadad_Aula_Materia'].get((aula, materia), {}).get('compatible', 0)
    for aula in model.Aulas for materia in model.Materias
})  # Compatibilidad entre aulas y materias (0 o 1)
# Relación entre profesores y las materias que pueden enseñar
model.Relacion_Profesor_Materia = pyo.Param(
    model.Profesores, model.MateriasPorBloqueExpandido,
    initialize={
        (profe_id, (bloque, materia_id)): 1 if materia_id in datos['Materias_por_Profesor'][profe_id] else 0
        for profe_id in model.Profesores
        for (bloque, materia_id) in materias_bloque_expandidas
    }
)

# %%
# Variables

X_index = [
    (p, bloque, m, a, bh)
    for p in datos['Profesores_Totales']
    for (bloque, m) in materias_bloque_expandidas
    if m in datos['Materias_por_Profesor'].get(p, [])
    for a in datos['Aulas']
    if datos['Compatibiliadad_Aula_Materia'].get((a, m), {}).get('compatible', 0) == 1
    for bh in [(d, h) for d in datos['Dia'] for h in datos['Hora']]
]


PROFESOR = 0
BLOQUE = 1
MATERIA = 2
AULA = 3
EDIFICIO = 4
DIA = 5
HORA = 6

# X_Index 
#[(100004288, 'ARQBLO1', 1, (102, 5), (1, 1))
# Model.X tiene la siguiente estructura para sus indices, pyomo aplana las tuplas :
# (100004288, ARQBLO1, 1, 102, 5, 1, 1) 

model.X = pyo.Var(X_index, domain=pyo.Binary)

# Variables generales: profesor puede enseñar materia (relación) - incluye imaginarios
Y_index = [(p, m) for p in datos['Profesores_Totales'] for m in datos['Materias_por_Profesor'].get(p, [])]
model.Y = pyo.Var(Y_index, domain=pyo.Binary)

# Variables generales: profesor tiene asignada la materia
Y_hat_index = [(p, bloque, m) for p in datos['Profesores_Totales'] for (bloque, m) in materias_bloque_expandidas]
model.Y_hat = pyo.Var(Y_hat_index, domain=pyo.Binary)


# Variables generales: aula asignada a materia (sin cambios)
Z_index = [(aula, edificio, materia) 
           for ((aula, edificio), materia), val in datos['Compatibiliadad_Aula_Materia'].items() 
           if val['compatible'] == 1]
model.Z = pyo.Var(Z_index, domain=pyo.Binary)

# Variables generales: materia impartida en dia d
Z_hat_index = [(bloque, m, d) for (bloque, m) in materias_bloque_expandidas for d in datos['Dia']]
model.Z_hat = pyo.Var(Z_hat_index, domain=pyo.Binary)


# # Variable Materia X es dada en hora H el dia D
S_Index = [(bloque, m, h, d) for (bloque, m) in materias_bloque_expandidas for h in datos['Hora'] for d in datos['Dia']]
model.S = pyo.Var(S_Index, domain=pyo.Binary)

model.U = pyo.Var(
    [(aula, edificio, bloque, materia)
     for (aula, edificio) in model.Aulas
     for (bloque, materia) in model.MateriasPorBloqueExpandido],
    domain=pyo.Binary
)





print(f"Variables reducidas de {len(datos['Profesores_Totales'])*len(datos['id_Materias'])*len(datos['Aulas'])*len(datos['Dia'])*len(datos['Hora'])} a {len(X_index)}")
# Out:
# Variables reducidas de 22932000 a 1899450

# %%
def vincular_X_con_U_rule(model, p, bloque, m, aula, edificio, dia, hora):
    return model.X[p, bloque, m, aula, edificio, dia, hora] <= model.U[aula, edificio, bloque, m]

model.Vincular_X_con_U = pyo.Constraint(X_index, rule=vincular_X_con_U_rule)


def ubicacion_unica_para_bloque_materia_rule(model, bloque, m):
    return sum(model.U[aula, edificio, bloque, m] for (aula, edificio) in model.Aulas) == 1

model.Ubicacion_Unica_BloqueMateria = pyo.Constraint(model.MateriasPorBloqueExpandido, rule=ubicacion_unica_para_bloque_materia_rule)

# %%
# def no_solapamiento_en_bloque_rule(model, bloque, dia, hora):
#     # Suma todas las materias de ese bloque en ese día y hora
#     return sum(model.S[bloque, m, hora, dia] for m in model.MateriasPorBloque[bloque]) <= 1

# model.NoSolapamientoEnBloque = pyo.Constraint(
#     model.Bloques,
#     model.Dias,
#     model.Hora,
#     rule=no_solapamiento_en_bloque_rule
# )

# %%
# Eliminar versión anterior si existe
if hasattr(model, 'Restriccion_Materia_Tiene_Profe'):
    model.del_component(model.Restriccion_Materia_Tiene_Profe)

# Regla adaptada
def materia_tiene_profe_rule(model, bloque, materia):
    return sum(
        model.Y_hat[p, bloque, materia] * model.Relacion_Profesor_Materia[p, (bloque, materia)]
        for p in model.Profesores
    ) == 1

# Restricción sobre MateriasPorBloqueExpandido
model.Restriccion_Materia_Tiene_Profe = pyo.Constraint(
    model.MateriasPorBloqueExpandido,
    rule=materia_tiene_profe_rule
)

# %%
# Construir el conjunto plano (lista) de (profesor, bloque, materia) válidos
tripletes = []
for p in model.Profesores:
    for bloque in model.Bloques:
        for m in model.MateriasPorBloque[bloque]:
            tripletes.append((p, bloque, m))

# Crear un Set en el modelo con esos índices
model.IndicesHorasSemanales = pyo.Set(initialize=tripletes, dimen=3)

# Construir diccionario para acceder rápido a los índices de X
indices_X_por_tripleta = {}
for idx in model.X.index_set():
    p = idx[PROFESOR]
    bloque = idx[BLOQUE]
    m = idx[MATERIA]
    indices_X_por_tripleta.setdefault((p, bloque, m), []).append(idx)

# Función regla que ahora toma solo 3 argumentos (p, bloque, m)
def horas_semana_materia_rule(model, p, bloque, m):
    indices = indices_X_por_tripleta.get((p, bloque, m), [])
    suma = sum(model.X[idx] for idx in indices)
    return suma == datos['Horas_Semana_Materia'][m] * model.Y_hat[p, bloque, m]

# Eliminar restricción si ya existe
if hasattr(model, 'Restriccion_Horas_Semanales'):
    model.del_component(model.Restriccion_Horas_Semanales)

# Crear la restricción usando el conjunto plano
model.Restriccion_Horas_Semanales = pyo.Constraint(
    model.IndicesHorasSemanales, rule=horas_semana_materia_rule
)

# %%
#Funciona No solapamiento de aulas
if hasattr(model, 'Restriccion_Aula_Unica'):
    model.del_component(model.Restriccion_Aula_Unica)

# Precomputar las combinaciones de aula, edificio, día y hora
solapamientos = {}

for idx in model.X:
    aula = idx[AULA]
    edificio = idx[EDIFICIO]
    dia = idx[DIA]
    hora = idx[HORA]
    
    if (aula, edificio, dia, hora) not in solapamientos:
        solapamientos[(aula, edificio, dia, hora)] = []

    solapamientos[(aula, edificio, dia, hora)].append(model.X[idx])

# Restricción para el no solapamiento de aulas
def no_solapamiento_aula_rule(model, aula_id, edificio_id, dia, hora):
    if (aula_id, edificio_id, dia, hora) not in solapamientos:
        return pyo.Constraint.Skip  # Si no existe ninguna asignación para esa combinación

    exprs = solapamientos[(aula_id, edificio_id, dia, hora)]
    return sum(exprs) <= 1

# Aplicamos la restricción optimizada
model.Restriccion_Aula_Unica = pyo.Constraint(
    model.Aulas, model.BloquesHorarios,
    rule=no_solapamiento_aula_rule
)

# %%
# # Precalcular los índices por profesor
# indices_por_profesor = {p: [] for p in model.Profesores}

# for idx in model.X:
#     profesor = idx[PROFESOR]
#     if profesor in indices_por_profesor:
#         indices_por_profesor[profesor].append(idx)

# # Eliminar restricciones si ya existen
# if hasattr(model, 'Restriccion_Max_Horas_Profesor'):
#     model.del_component(model.Restriccion_Max_Horas_Profesor)

# tipo_contrato_por_profesor = datos['Tipo_Contrato']
# detalles_contratos = datos['Detalles_Contratos']

# # Restricción máxima horas por profesor
# def max_horas_profesor_rule(model, p):
#     if (
#         p not in tipo_contrato_por_profesor
#         or p not in indices_por_profesor
#         or not indices_por_profesor[p]  # Lista vacía
#     ):
#         return pyo.Constraint.Skip

#     contrato_id = tipo_contrato_por_profesor[p]
#     max_horas = detalles_contratos[contrato_id]['max']

#     # Sumar las variables X asignadas a ese profesor (cada X representa 1 hora en un bloque/materia/aula/...)
#     return sum(model.X[idx] for idx in indices_por_profesor[p]) <= max_horas

# model.Restriccion_Max_Horas_Profesor = pyo.Constraint(model.Profesores, rule=max_horas_profesor_rule)

# %%
# Eliminar restricción si ya existe
if hasattr(model, 'Restriccion_Ubicacion_Unica_Materia'):
    model.del_component(model.Restriccion_Ubicacion_Unica_Materia)

def ubicacion_unica_por_materia_rule(model, m):
    # Suma de todas las asignaciones Z para la materia m, sobre todas aulas y edificios
    return sum(model.Z[aula, edificio, m] for (aula, edificio, mm) in model.Z.index_set() if mm == m) == 1

model.Restriccion_Ubicacion_Unica_Materia = pyo.Constraint(
    model.Materias, rule=ubicacion_unica_por_materia_rule
)

# %%
# Eliminar restricción si ya existe
if hasattr(model, 'Restriccion_Profesor_Unico'):
    model.del_component(model.Restriccion_Profesor_Unico)

# Precomputar las asignaciones por profesor, día y hora
solapamientos_profesor = {}

for idx in model.X:
    profesor = idx[PROFESOR]
    dia = idx[DIA]
    hora = idx[HORA]

    if (profesor, dia, hora) not in solapamientos_profesor:
        solapamientos_profesor[(profesor, dia, hora)] = []

    solapamientos_profesor[(profesor, dia, hora)].append(model.X[idx])

# Restricción que limita al profesor a no impartir más de una materia simultáneamente
def no_solapamiento_profesor_rule(model, p, d, h):
    if (p, d, h) not in solapamientos_profesor:
        return pyo.Constraint.Skip
    return sum(solapamientos_profesor[(p, d, h)]) <= 1

model.Restriccion_Profesor_Unico = pyo.Constraint(
    model.Profesores, model.Dias, model.Hora,
    rule=no_solapamiento_profesor_rule
)

# %%
# # Eliminar restricción si existe
# if hasattr(model, 'Restriccion_Profesor_Compatible'):
#     model.del_component(model.Restriccion_Profesor_Compatible)

# # Precalcular variables X que son incompatibles (Relacion_Profesor_Materia == 0)
# x_incompatibles_profesor = [
#     model.X[idx] for idx in model.X.index_set()
#     if (idx[0], idx[1], idx[2]) not in model.Relacion_Profesor_Materia or model.Relacion_Profesor_Materia[idx[0], idx[1], idx[2]] == 0
# ]

# # Restricción: esas X deben ser 0
# def profesor_compatible_rule(model, i):
#     return x_incompatibles_profesor[i] == 0

# model.Restriccion_Profesor_Compatible = pyo.Constraint(
#     range(len(x_incompatibles_profesor)),
#     rule=profesor_compatible_rule
# )

# %%
# # Eliminar restricción si existe
# if hasattr(model, 'Restriccion_Aula_Compatible'):
#     model.del_component(model.Restriccion_Aula_Compatible)

# # Precalcular X que tengan aula incompatible con la materia
# x_incompatibles_aula = [
#     model.X[idx] for idx in model.X.index_set()
#     if (idx[3], idx[4], idx[2]) not in model.Compatibilidad_Aula_Materia or model.Compatibilidad_Aula_Materia[idx[3], idx[4], idx[2]] == 0
# ]

# # Restricción: esas X deben ser 0
# def aula_compatible_rule(model, i):
#     return x_incompatibles_aula[i] == 0

# model.Restriccion_Aula_Compatible = pyo.Constraint(
#     range(len(x_incompatibles_aula)),
#     rule=aula_compatible_rule
# )

# %%
# # Eliminar restricciones si existen
# if hasattr(model, 'Relacion_X_Z_1'):
#     model.del_component(model.Relacion_X_Z_1)
# if hasattr(model, 'Relacion_X_Z_2'):
#     model.del_component(model.Relacion_X_Z_2)

# X_index = model.X.index_set()

# def relacion_X_Z_rule_1(model, p, b, m, aula, edificio, dia, hora):
#     # Acceso directo con control de existencia para evitar error
#     if (aula, edificio, m) in model.Z:
#         return model.X[p, b, m, aula, edificio, dia, hora] <= model.Z[aula, edificio, m]
#     else:
#         # Si no existe Z para esta combinación, no permitir X=1
#         return model.X[p, b, m, aula, edificio, dia, hora] == 0

# def relacion_X_Z_rule_2(model, p, b, m, aula, edificio, dia, hora):
#     if (aula, edificio, m) in model.Z:
#         return model.Z[aula, edificio, m] >= model.X[p, b, m, aula, edificio, dia, hora]
#     else:
#         # Si no existe Z, no permitir asignación
#         return model.X[p, b, m, aula, edificio, dia, hora] == 0

# model.Relacion_X_Z_1 = pyo.Constraint(X_index, rule=relacion_X_Z_rule_1)
# model.Relacion_X_Z_2 = pyo.Constraint(X_index, rule=relacion_X_Z_rule_2)

# %%
# # --- Restricción: Las clases de una materia en un día deben ser consecutivas ---

# # Eliminar componente anterior si ya existe
# if hasattr(model, 'Restriccion_Consecutividad_Materia_Dia'):
#     model.del_component(model.Restriccion_Consecutividad_Materia_Dia)

# # Precalcular clases posibles por (materia, día, hora)
# clases_por_materia_dia_hora = {}

# for (p, b, m, aula, edificio, d, h) in model.X.index_set():
#     key = (m, d, h)
#     if key not in clases_por_materia_dia_hora:
#         clases_por_materia_dia_hora[key] = []
#     clases_por_materia_dia_hora[key].append(model.X[p, b, m, aula, edificio, d, h])

# # Definir el conjunto de índices válidos (no incluye la última hora del día)
# consecutividad_index = [
#     (m, d, h)
#     for m in datos['id_Materias']
#     for d in datos['Dia']
#     for h in datos['Hora'][:-1]  # Excluimos la última hora para h+1
# ]

# # Regla: si hay clase en h+1, debe haber clase en h
# def consecutividad_materia_dia_rule(model, m, d, h):
#     clases_h = clases_por_materia_dia_hora.get((m, d, h), [])
#     clases_h1 = clases_por_materia_dia_hora.get((m, d, h + 1), [])

#     # Si no hay clases posibles en h+1, saltar restricción
#     if not clases_h1:
#         return pyo.Constraint.Skip

#     return sum(clases_h1) <= sum(clases_h)

# # Crear restricción en el modelo
# model.Restriccion_Consecutividad_Materia_Dia = pyo.Constraint(
#     consecutividad_index,
#     rule=consecutividad_materia_dia_rule
# )

# %%
# # ==============================
# # Restricción: No solapamiento entre materias del mismo bloque
# # ==============================

# # Precalcular combinaciones únicas de materias por bloque (sin repetir ni reflejar pares)
# materias_mismo_bloque_sin_repetir = []

# for bloque in model.Bloques:
#     materias = list(model.MateriasPorBloque[bloque])
#     for i in range(len(materias)):
#         for j in range(i + 1, len(materias)):
#             m1, m2 = materias[i], materias[j]
#             materias_mismo_bloque_sin_repetir.append((bloque, m1, m2))

# # Crear restricción con base en las combinaciones precalculadas
# model.NoSolapamientoMateriasEnMismoBloque = pyo.Constraint(
#     [
#         (bloque, m1, m2, d, h)
#         for (bloque, m1, m2) in materias_mismo_bloque_sin_repetir
#         for d in datos['Dia']
#         for h in datos['Hora']
#     ],
#     rule=lambda model, bloque, m1, m2, d, h:
#         model.S[bloque, m1, h, d] + model.S[bloque, m2, h, d] <= 1
# )

# %%
if hasattr(model, 'objetivo_dummy'):
    model.del_component(model.objetivo_dummy)

model.objetivo_dummy = pyo.Objective(expr=1, sense=pyo.minimize)

# %%
# Obtener todas las restricciones activas del modelo y almacenarlas en una lista
restricciones = []

print("Restricciones definidas en el modelo:")
for nombre, componente in model.component_map(pyo.Constraint, active=True).items():
    restricciones.append(nombre)
    print(f"- {nombre}")

# Ahora tienes una lista con los nombres de las restricciones
# Puedes usarla después si necesitas procesarlas de otra forma
# Out:
# Restricciones definidas en el modelo:
# - Vincular_X_con_U
# - Ubicacion_Unica_BloqueMateria
# - Restriccion_Materia_Tiene_Profe
# - Restriccion_Horas_Semanales
# - Restriccion_Aula_Unica
# - Restriccion_Ubicacion_Unica_Materia
# - Restriccion_Profesor_Unico

# %%
def resolver_modelo(model, mipgap=0.02, threads=4, emphasis=1):
    from pyomo.opt import SolverFactory, TerminationCondition

    solver = SolverFactory('cplex')

    if not solver.available():
        raise RuntimeError("CPLEX no está disponible. Verifica la instalación o el PATH.")

    resultado = solver.solve(model, tee=True)

    # Verificar si la solución fue óptima o factible
    condicion = resultado.solver.termination_condition
    if condicion in [TerminationCondition.optimal, TerminationCondition.feasible]:
        print(f"Solución encontrada: {condicion}")
    else:
        print(f"Problema durante la resolución: {condicion}")
        print("Revisa el modelo o ajusta parámetros del solver.")

    return resultado

# %%
import pandas as pd
from collections import defaultdict
import pyomo.environ as pyo  # Asegúrate de tener esta importación si usas Pyomo

def mostrar_bloque(dia, hora_inicio, hora_fin):
    dias = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes']
    dia_str = dias[dia - 1] if 1 <= dia <= 5 else f"Día{dia}"
    hora_inicio_real = 7 + hora_inicio
    hora_fin_real = 7 + hora_fin
    return f"{dia_str} {hora_inicio_real:02d}:00 - {hora_fin_real:02d}:00"

def mostrar_asignacion(model, datos):
    sesiones = defaultdict(list)

    # Agrupar sesiones por clave común (profesor, bloque, materia, aula, edificio, día)
    for idx in model.X:
        if pyo.value(model.X[idx]) > 0.5:
            p, bloque, m, aula, edificio_id, dia, hora = idx
            sesiones[(p, bloque, m, aula, edificio_id, dia)].append(hora)

    agrupadas = defaultdict(list)

    # Agrupar horarios consecutivos por sesión
    for (p, bloque, m, aula, edificio_id, dia), horas in sesiones.items():
        horas = sorted(horas)
        bloques_horarios = []
        inicio = fin = horas[0]

        for h in horas[1:]:
            if h == fin + 1:
                fin = h
            else:
                bloques_horarios.append((inicio, fin + 1))
                inicio = fin = h
        bloques_horarios.append((inicio, fin + 1))  # último bloque

        for hora_inicio, hora_fin in bloques_horarios:
            horario_str = mostrar_bloque(dia, hora_inicio, hora_fin)
            agrupadas[(p, bloque, m, aula, edificio_id)].append(horario_str)

    asignaciones = []

    print("\nAsignaciones de profesores, materias, aulas y horarios:")
    for (p, bloque, m, aula, edificio_id), lista_horarios in agrupadas.items():
        profesor_nombre = datos.get('nombres_profesor', {}).get(p, str(p))
        materia_nombre = datos.get('nombres_materia', {}).get(m, str(m))
        edificio_nombre = datos.get('Edificios', {}).get(edificio_id, f"Edificio {edificio_id}")
        programa_educativo = datos.get('Bloques', {}).get(bloque, {}).get('programa_educativo', 'Desconocido')

        horarios_combinados = "; ".join(lista_horarios)

        print(f"Profesor: {profesor_nombre} | Materia: {materia_nombre} | Aula: {aula} "
              f"(Edificio {edificio_nombre}) | Horarios: {horarios_combinados} | "
              f"Bloque: {bloque} | Programa: {programa_educativo}")

        asignaciones.append({
            'id_materia': m,
            'Materia': materia_nombre,
            'Bloque': bloque,
            'Programa_Educativo': programa_educativo,
            'Profesor': profesor_nombre,
            'Edificio': edificio_nombre,
            'Aula': aula,
            'Horarios': horarios_combinados
        })

    # Exportar a Excel
    df = pd.DataFrame(asignaciones, columns=[
        'id_materia',
        'Materia',
        'Bloque',
        'Programa_Educativo',
        'Profesor',
        'Edificio',
        'Aula',
        'Horarios'
    ])
    df.to_excel('asignaciones.xlsx', index=False)
    print("\nArchivo 'asignaciones.xlsx' creado con éxito.")

    return asignaciones




def mostrar_horarios_por_bloque(asignaciones):
    from collections import defaultdict

    dias_orden = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes']

    bloques = defaultdict(list)

    for asignacion in asignaciones:
        bloque = asignacion['Bloque']
        materia = asignacion['Materia']
        profesor = asignacion['Profesor']
        aula = asignacion['Aula']
        edificio = asignacion['Edificio']
        horarios = asignacion['Horarios']
        programa = asignacion['Programa_Educativo']

        # Separar por cada horario individual
        for horario in horarios.split('; '):
            dia, resto = horario.split(' ', 1)
            bloques[(bloque, programa)].append({
                'Día': dia,
                'Hora': resto,
                'Materia': materia,
                'Profesor': profesor,
                'Aula': aula,
                'Edificio': edificio
            })

    print("\n📘 Horarios agrupados por Bloque y Programa:\n")

    for (bloque, programa), asigns in sorted(bloques.items()):
        print("=" * 70)
        print(f"🔹 BLOQUE: {bloque} | PROGRAMA EDUCATIVO: {programa}")
        print("=" * 70)

        # Ordenar por día y hora
        asigns.sort(key=lambda x: (dias_orden.index(x['Día']), x['Hora']))

        # Cabecera estilo tabla
        print(f"{'Día':<12} {'Hora':<15} {'Materia':<35} {'Profesor':<30} {'Aula':<10} {'Edificio'}")
        print("-" * 130)

        for a in asigns:
            print(f"{a['Día']:<12} {a['Hora']:<15} {a['Materia'][:34]:<35} "
                  f"{a['Profesor'][:29]:<30} {a['Aula']:<10} {a['Edificio']}")
        print()  # Espacio entre bloques

    # Exportar a Excel (ordenado también)
    filas = []
    for (bloque, programa), asigns in bloques.items():
        for a in asigns:
            filas.append({
                'Bloque': bloque,
                'Programa_Educativo': programa,
                'Día': a['Día'],
                'Hora': a['Hora'],
                'Materia': a['Materia'],
                'Profesor': a['Profesor'],
                'Aula': a['Aula'],
                'Edificio': a['Edificio']
            })

    df_bloques = pd.DataFrame(filas)
    df_bloques['Día'] = pd.Categorical(df_bloques['Día'], categories=dias_orden, ordered=True)
    df_bloques.sort_values(['Bloque', 'Programa_Educativo', 'Día', 'Hora'], inplace=True)
    df_bloques.to_excel('horarios_por_bloque.xlsx', index=False)
    print("📁 Archivo 'horarios_por_bloque.xlsx' creado con éxito.\n")

# %%
# Resolver el modelo
resultados = resolver_modelo(model)

# Verificar si encontró solución
if (resultados.solver.status == pyo.SolverStatus.ok and
    resultados.solver.termination_condition == pyo.TerminationCondition.optimal):

    print("Solución óptima encontrada.\n")
    asignaciones_lista = mostrar_asignacion(model,datos)
    mostrar_horarios_por_bloque(asignaciones_lista)


    import pandas as pd
    df = pd.DataFrame(asignaciones_lista)
    profesores_usados = {a['Profesor'] for a in asignaciones_lista}
    total_usados = len(profesores_usados)
    total_profesores = datos['Profesores_Totales']

    print(f"\nProfesores asignados: {total_usados} de {len(total_profesores)}")

    # Expandir horarios por fila para detectar solapes
    df_exploded = df.copy()
    df_exploded['Horario'] = df_exploded['Horarios'].str.split('; ')
    df_exploded = df_exploded.explode('Horario')

    # Verificar solapes
    solapes_profesor = df_exploded[df_exploded.duplicated(['Profesor', 'Horario'], keep=False)]
    solapes_aula = df_exploded[df_exploded.duplicated(['Aula', 'Edificio', 'Horario'], keep=False)]

    if solapes_profesor.empty:
        print("✅ No hay solapamientos de profesor.")
    else:
        print("⚠️ Hay solapamientos de profesor:")
        print(solapes_profesor[['Profesor', 'Materia', 'Horario']].drop_duplicates())

    if solapes_aula.empty:
        print("✅ No hay solapamientos de aula.")
    else:
        print("⚠️ Hay solapamientos de aula:")
        print(solapes_aula[['Aula', 'Edificio', 'Materia', 'Horario']].drop_duplicates())

else:
    print("No se encontró solución óptima.")
    print("Estado:", resultados.solver.status)
    print("Condición de terminación:", resultados.solver.termination_condition)
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 22.1.1.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2022.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\bdgae\AppData\Local\Temp\tmphlokh4zw.cplex.log' open.
# CPLEX> Problem 'C:\Users\bdgae\AppData\Local\Temp\tmpfdfpbchy.pyomo.lp' read.
# Read time = 11.00 sec. (304.87 ticks)
# CPLEX> Problem name         : C:\Users\bdgae\AppData\Local\Temp\tmpfdfpbchy.pyomo.lp
# Objective sense      : Minimize
# Variables            : 1946440  [Fix: 1,  Binary: 1946439]
# Objective nonzeros   :       1
# Linear constraints   : 1940314  [Less: 1904450,  Equal: 35864]
#   Nonzeros           : 9544806
#   RHS nonzeros       :    5192
#
# Variables            : Min LB: 0.000000         Max UB: 1.000000
# Objective nonzeros   : Min   : 1.000000         Max   : 1.000000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 7.000000
#   RHS nonzeros       : Min   : 1.000000         Max   : 1.000000
# CPLEX> Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# Tried aggregator 2 times.
# Aggregator has done 91 substitutions...
# MIP Presolve eliminated 1629715 rows and 40326 columns.
# MIP Presolve modified 304850 coefficients.
# Aggregator did 91 substitutions.
# Reduced MIP has 310508 rows, 1906023 columns, and 7909699 nonzeros.
# Reduced MIP has 1906023 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 31.48 sec. (18902.96 ticks)
# Found incumbent of value 1.000000 after 57.50 sec. (28741.36 ticks)
#
# Root node processing (before b&c):
#   Real time             =   58.41 sec. (28815.89 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =   58.41 sec. (28815.89 ticks)
#
# Solution pool: 1 solution saved.
#
# MIP - Integer optimal solution:  Objective =  1.0000000000e+00
# Solution time =   58.42 sec.  Iterations = 0  Nodes = 0 (1)
# Deterministic time = 28821.46 ticks  (493.34 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\bdgae\AppData\Local\Temp\tmptd9cnru4.cplex.sol'.
# CPLEX> Solución encontrada: optimal
# Solución óptima encontrada.
#
#
# Asignaciones de profesores, materias, aulas y horarios:
# Profesor: GARCIA - SALAZAR RUBEN | Materia: Teoría de la Arquitectura | Aula: 206 (Edificio EMA5) | Horarios: Jueves 10:00 - 11:00; Jueves 16:00 - 17:00; Viernes 15:00 - 16:00 | Bloque: ARQBLO1 | Programa: ARQ
# Profesor: GARCIA - SALAZAR RUBEN | Materia: Teoría de la Arquitectura | Aula: 204 (Edificio EMA5) | Horarios: Martes 17:00 - 18:00; Miércoles 09:00 - 10:00; Jueves 15:00 - 16:00 | Bloque: ARQBLO2 | Programa: ARQ
# Profesor: GARCIA - SALAZAR RUBEN | Materia: Teoría de la Arquitectura | Aula: 306 (Edificio EMA6) | Horarios: Lunes 13:00 - 14:00; Lunes 15:00 - 16:00; Miércoles 15:00 - 16:00 | Bloque: ARQBLO8 | Programa: ARQ
# Profesor: RAMIREZ - MENDOZA MARCELINO | Materia: Investigación para la Arquitec | Aula: 104 (Edificio EMA7) | Horarios: Lunes 12:00 - 13:00; Martes 14:00 - 15:00; Miércoles 14:00 - 15:00 | Bloque: ARQBLO6 | Programa: ARQ
# Profesor: ALONSO - PEREZ CARLOS | Materia: Hist. y Tendencias Urbano Arq. | Aula: 302 (Edificio EMA6) | Horarios: Martes 14:00 - 15:00; Viernes 08:00 - 09:00; Viernes 11:00 - 12:00 | Bloque: ARQBLO1 | Programa: ARQ
# Profesor: ALONSO - PEREZ CARLOS | Materia: Dibujo I | Aula: 107 (Edificio EMA5) | Horarios: Martes 15:00 - 17:00; Jueves 11:00 - 12:00; Viernes 12:00 - 13:00 | Bloque: ARQBLO3 | Programa: ARQ
# Profesor: ALONSO - PEREZ CARLOS | Materia: Hist. y Tendencias Urbano Arq. | Aula: 303 (Edificio EMA6) | Horarios: Miércoles 13:00 - 14:00; Jueves 10:00 - 11:00; Viernes 10:00 - 11:00 | Bloque: ARQBLO5 | Programa: ARQ
# Profesor: ALONSO - PEREZ CARLOS | Materia: Dibujo I | Aula: 302 (Edificio EMA6) | Horarios: Lunes 12:00 - 13:00; Martes 10:00 - 11:00; Miércoles 14:00 - 15:00; Jueves 08:00 - 09:00 | Bloque: ARQBLO6 | Programa: ARQ
# Profesor: ALONSO - PEREZ CARLOS | Materia: Dibujo I | Aula: 203 (Edificio EMA7) | Horarios: Lunes 08:00 - 10:00; Lunes 17:00 - 18:00; Martes 11:00 - 12:00 | Bloque: ARQBLO8 | Programa: ARQ
# Profesor: ALONSO - PEREZ CARLOS | Materia: Hist. y Tendencias Urbano Arq. | Aula: 104 (Edificio EMA5) | Horarios: Martes 08:00 - 09:00; Miércoles 09:00 - 11:00 | Bloque: ARQBLO10 | Programa: ARQ
# Profesor: AGUILAR - TRONCOZO CHRISTIAN | Materia: Investigación para la Arquitec | Aula: 306 (Edificio EMA5) | Horarios: Lunes 15:00 - 16:00; Lunes 17:00 - 18:00; Jueves 15:00 - 16:00 | Bloque: ARQBLO2 | Programa: ARQ
# Profesor: AGUILAR - TRONCOZO CHRISTIAN | Materia: Investigación para la Arquitec | Aula: 307 (Edificio EMA7) | Horarios: Miércoles 09:00 - 10:00; Miércoles 14:00 - 15:00; Miércoles 16:00 - 17:00 | Bloque: ARQBLO10 | Programa: ARQ
# Profesor: CUAPA - CANTO ROSALBA | Materia: Matem. para la Arquitectura I | Aula: 102 (Edificio EMA6) | Horarios: Martes 13:00 - 14:00; Miércoles 09:00 - 10:00; Jueves 12:00 - 13:00; Viernes 09:00 - 10:00 | Bloque: ARQBLO2 | Programa: ARQ
# Profesor: CUAPA - CANTO ROSALBA | Materia: Matem. para la Arquitectura I | Aula: 305 (Edificio EMA7) | Horarios: Lunes 14:00 - 16:00; Martes 15:00 - 16:00; Miércoles 17:00 - 18:00 | Bloque: ARQBLO10 | Programa: ARQ
# Profesor: DIAZ - CARRANZA GUADALUPE | Materia: Introduccion a la Biologia | Aula: 303 (Edificio EMA6) | Horarios: Lunes 09:00 - 10:00; Lunes 11:00 - 12:00; Lunes 17:00 - 18:00; Jueves 11:00 - 12:00; Jueves 13:00 - 14:00 | Bloque: BIOBLO1 | Programa: BIO
# Profesor: DIAZ - CARRANZA GUADALUPE | Materia: Introduccion a la Biologia | Aula: 201 (Edificio EMA7) | Horarios: Martes 12:00 - 13:00; Miércoles 08:00 - 09:00; Miércoles 14:00 - 15:00; Jueves 09:00 - 10:00; Jueves 16:00 - 17:00 | Bloque: BIOBLO7 | Programa: BIO
# Profesor: ROSAS - LORANCA ROBERTO | Materia: Dibujo I | Aula: 103 (Edificio EMA7) | Horarios: Lunes 10:00 - 11:00; Martes 09:00 - 10:00; Jueves 09:00 - 10:00; Viernes 15:00 - 16:00 | Bloque: ARQBLO4 | Programa: ARQ
# Profesor: ROSAS - LORANCA ROBERTO | Materia: Taller de Diseño Básico | Aula: 204 (Edificio EMA6) | Horarios: Lunes 08:00 - 09:00; Miércoles 10:00 - 11:00; Jueves 11:00 - 12:00; Viernes 12:00 - 15:00 | Bloque: ARQBLO5 | Programa: ARQ
# Profesor: ROSAS - LORANCA ROBERTO | Materia: Dibujo I | Aula: 303 (Edificio EMA5) | Horarios: Lunes 09:00 - 10:00; Lunes 13:00 - 14:00; Jueves 17:00 - 18:00; Viernes 08:00 - 09:00 | Bloque: ARQBLO7 | Programa: ARQ
# Profesor: ROSAS - LORANCA ROBERTO | Materia: Dibujo I | Aula: 106 (Edificio EMA5) | Horarios: Lunes 11:00 - 12:00; Jueves 10:00 - 11:00; Viernes 10:00 - 11:00; Viernes 16:00 - 17:00 | Bloque: ARQBLO9 | Programa: ARQ
# Profesor: JAEN - VARGAS MARIA GUADALUPE | Materia: Geometría Descriptiva | Aula: 105 (Edificio EMA5) | Horarios: Lunes 09:00 - 10:00; Martes 09:00 - 10:00; Miércoles 09:00 - 10:00; Miércoles 15:00 - 16:00 | Bloque: ARQBLO1 | Programa: ARQ
# Profesor: JAEN - VARGAS MARIA GUADALUPE | Materia: Matem. para la Arquitectura I | Aula: 205 (Edificio EMA6) | Horarios: Jueves 17:00 - 18:00; Viernes 10:00 - 12:00; Viernes 17:00 - 18:00 | Bloque: ARQBLO1 | Programa: ARQ
# Profesor: JAEN - VARGAS MARIA GUADALUPE | Materia: Geometría Descriptiva | Aula: 206 (Edificio EMA6) | Horarios: Lunes 17:00 - 18:00; Martes 08:00 - 09:00; Jueves 15:00 - 16:00; Viernes 13:00 - 14:00 | Bloque: ARQBLO2 | Programa: ARQ
# Profesor: JAEN - VARGAS MARIA GUADALUPE | Materia: Geometría Descriptiva | Aula: 107 (Edificio EMA6) | Horarios: Martes 15:00 - 16:00; Jueves 08:00 - 09:00; Jueves 14:00 - 15:00; Jueves 16:00 - 17:00 | Bloque: ARQBLO3 | Programa: ARQ
# Profesor: JAEN - VARGAS MARIA GUADALUPE | Materia: Geometría Descriptiva | Aula: 106 (Edificio EMA6) | Horarios: Martes 14:00 - 15:00; Miércoles 08:00 - 09:00; Jueves 11:00 - 12:00; Viernes 12:00 - 13:00 | Bloque: ARQBLO4 | Programa: ARQ
# Profesor: JAEN - VARGAS MARIA GUADALUPE | Materia: Matem. para la Arquitectura I | Aula: 107 (Edificio EMA5) | Horarios: Lunes 11:00 - 12:00; Lunes 15:00 - 16:00; Martes 17:00 - 18:00; Miércoles 17:00 - 18:00 | Bloque: ARQBLO4 | Programa: ARQ
# Profesor: JAEN - VARGAS MARIA GUADALUPE | Materia: Geometría Descriptiva | Aula: 206 (Edificio EMA6) | Horarios: Martes 12:00 - 13:00; Miércoles 16:00 - 17:00; Viernes 09:00 - 10:00; Viernes 14:00 - 15:00 | Bloque: ARQBLO6 | Programa: ARQ
# Profesor: JAEN - VARGAS MARIA GUADALUPE | Materia: Geometría Descriptiva | Aula: 104 (Edificio EMA7) | Horarios: Lunes 16:00 - 17:00; Jueves 13:00 - 14:00; Viernes 08:00 - 09:00; Viernes 16:00 - 17:00 | Bloque: ARQBLO7 | Programa: ARQ
# Profesor: OCHOA - BILBAO IGNACIO | Materia: Investigación para la Arquitec | Aula: 208 (Edificio EMA6) | Horarios: Lunes 08:00 - 09:00; Jueves 17:00 - 18:00; Viernes 11:00 - 12:00 | Bloque: ARQBLO1 | Programa: ARQ
# Profesor: OCHOA - BILBAO IGNACIO | Materia: Teoría de la Arquitectura | Aula: 202 (Edificio EMA6) | Horarios: Martes 09:00 - 10:00; Miércoles 09:00 - 10:00; Viernes 09:00 - 10:00 | Bloque: ARQBLO3 | Programa: ARQ
# Profesor: OCHOA - BILBAO IGNACIO | Materia: Geometría Descriptiva | Aula: 201 (Edificio EMA6) | Horarios: Lunes 11:00 - 12:00; Lunes 13:00 - 14:00; Miércoles 08:00 - 09:00; Jueves 10:00 - 11:00 | Bloque: ARQBLO8 | Programa: ARQ
# Profesor: CONTRERAS - ALVARADO MINERVA | Materia: Introduccion a la Biologia | Aula: 307 (Edificio EMA5) | Horarios: Lunes 10:00 - 12:00; Miércoles 09:00 - 10:00; Miércoles 16:00 - 17:00; Viernes 10:00 - 11:00 | Bloque: BIOBLO2 | Programa: BIO
# Profesor: CONTRERAS - ALVARADO MINERVA | Materia: Introduccion a la Biologia | Aula: 102 (Edificio EMA5) | Horarios: Lunes 08:00 - 09:00; Miércoles 11:00 - 12:00; Jueves 11:00 - 12:00; Viernes 09:00 - 10:00; Viernes 12:00 - 13:00 | Bloque: BIOBLO3 | Programa: BIO
# Profesor: CONTRERAS - ALVARADO MINERVA | Materia: Introduccion a la Biologia | Aula: 105 (Edificio EMA7) | Horarios: Martes 13:00 - 15:00; Miércoles 15:00 - 16:00; Jueves 08:00 - 09:00; Jueves 16:00 - 17:00 | Bloque: BIOBLO4 | Programa: BIO
# Profesor: CONTRERAS - ALVARADO MINERVA | Materia: Introduccion a la Biologia | Aula: 108 (Edificio EMA7) | Horarios: Lunes 12:00 - 14:00; Lunes 17:00 - 18:00; Martes 17:00 - 18:00; Miércoles 12:00 - 13:00 | Bloque: BIOBLO5 | Programa: BIO
# Profesor: CONTRERAS - ALVARADO MINERVA | Materia: Introduccion a la Biologia | Aula: 307 (Edificio EMA7) | Horarios: Lunes 15:00 - 16:00; Jueves 10:00 - 11:00; Jueves 14:00 - 16:00; Viernes 13:00 - 14:00 | Bloque: BIOBLO6 | Programa: BIO
# Profesor: MALDONADO - CASTRO NAHELY | Materia: Dibujo I | Aula: 105 (Edificio EMA5) | Horarios: Lunes 16:00 - 17:00; Martes 12:00 - 13:00; Miércoles 14:00 - 15:00; Jueves 11:00 - 12:00 | Bloque: ARQBLO2 | Programa: ARQ
# Profesor: MALDONADO - CASTRO NAHELY | Materia: Investigación para la Arquitec | Aula: 306 (Edificio EMA6) | Horarios: Martes 17:00 - 18:00; Miércoles 13:00 - 14:00; Viernes 17:00 - 18:00 | Bloque: ARQBLO4 | Programa: ARQ
# Profesor: MALDONADO - CASTRO NAHELY | Materia: Matem. para la Arquitectura I | Aula: 107 (Edificio EMA7) | Horarios: Lunes 08:00 - 09:00; Lunes 12:00 - 13:00; Martes 10:00 - 11:00; Miércoles 09:00 - 10:00 | Bloque: ARQBLO5 | Programa: ARQ
# Profesor: MALDONADO - CASTRO NAHELY | Materia: Teoría de la Arquitectura | Aula: 203 (Edificio EMA6) | Horarios: Martes 08:00 - 09:00; Jueves 15:00 - 16:00; Viernes 14:00 - 15:00 | Bloque: ARQBLO6 | Programa: ARQ
# Profesor: MALDONADO - CASTRO NAHELY | Materia: Matem. para la Arquitectura I | Aula: 208 (Edificio EMA7) | Horarios: Lunes 15:00 - 16:00; Miércoles 08:00 - 09:00; Miércoles 10:00 - 11:00; Jueves 16:00 - 17:00 | Bloque: ARQBLO6 | Programa: ARQ
# Profesor: MALDONADO - CASTRO NAHELY | Materia: Taller de Diseño Básico | Aula: 302 (Edificio EMA5) | Horarios: Lunes 11:00 - 12:00; Lunes 17:00 - 18:00; Miércoles 11:00 - 12:00; Jueves 13:00 - 14:00; Viernes 08:00 - 09:00; Viernes 16:00 - 17:00 | Bloque: ARQBLO8 | Programa: ARQ
# Profesor: MALDONADO - CASTRO NAHELY | Materia: Investigación para la Arquitec | Aula: 302 (Edificio EMA7) | Horarios: Martes 14:00 - 15:00; Martes 16:00 - 17:00; Viernes 15:00 - 16:00 | Bloque: ARQBLO9 | Programa: ARQ
# Profesor: MORA - RODRIGUEZ DAVID | Materia: Matem. para la Arquitectura I | Aula: 103 (Edificio EMA6) | Horarios: Martes 10:00 - 11:00; Martes 13:00 - 14:00; Jueves 08:00 - 09:00; Viernes 11:00 - 12:00 | Bloque: ARQBLO3 | Programa: ARQ
# Profesor: MORA - RODRIGUEZ DAVID | Materia: Matem. para la Arquitectura I | Aula: 304 (Edificio EMA6) | Horarios: Lunes 15:00 - 16:00; Lunes 17:00 - 18:00; Martes 16:00 - 17:00; Jueves 15:00 - 16:00 | Bloque: ARQBLO7 | Programa: ARQ
# Profesor: MORA - RODRIGUEZ DAVID | Materia: Matem. para la Arquitectura I | Aula: 206 (Edificio EMA5) | Horarios: Martes 08:00 - 09:00; Miércoles 15:00 - 16:00; Jueves 11:00 - 12:00; Viernes 13:00 - 14:00 | Bloque: ARQBLO8 | Programa: ARQ
# Profesor: MORA - RODRIGUEZ DAVID | Materia: Matem. para la Arquitectura I | Aula: 207 (Edificio EMA6) | Horarios: Martes 17:00 - 18:00; Miércoles 10:00 - 11:00; Jueves 13:00 - 14:00; Jueves 17:00 - 18:00 | Bloque: ARQBLO9 | Programa: ARQ
# Profesor: DIAZ - DE ANDA ALFREDO | Materia: Biomatematicas I | Aula: 303 (Edificio EMA5) | Horarios: Lunes 08:00 - 09:00; Lunes 11:00 - 12:00; Lunes 14:00 - 15:00; Martes 11:00 - 12:00; Martes 17:00 - 18:00; Viernes 10:00 - 11:00; Viernes 15:00 - 16:00 | Bloque: BIOBLO2 | Programa: BIO
# Profesor: DIAZ - DE ANDA ALFREDO | Materia: Biomatematicas I | Aula: 103 (Edificio EMA5) | Horarios: Martes 10:00 - 11:00; Miércoles 10:00 - 11:00; Miércoles 14:00 - 15:00; Miércoles 17:00 - 18:00; Jueves 08:00 - 10:00; Viernes 08:00 - 09:00 | Bloque: BIOBLO3 | Programa: BIO
# Profesor: DIAZ - DE ANDA ALFREDO | Materia: Biomatematicas I | Aula: 107 (Edificio EMA7) | Horarios: Martes 08:00 - 09:00; Martes 13:00 - 14:00; Martes 15:00 - 16:00; Miércoles 08:00 - 09:00; Miércoles 16:00 - 17:00; Jueves 15:00 - 16:00; Viernes 12:00 - 13:00 | Bloque: BIOBLO5 | Programa: BIO
# Profesor: DIAZ - DE ANDA ALFREDO | Materia: Biomatematicas I | Aula: 301 (Edificio EMA6) | Horarios: Lunes 09:00 - 10:00; Lunes 15:00 - 16:00; Martes 12:00 - 13:00; Martes 14:00 - 15:00; Miércoles 09:00 - 10:00; Jueves 11:00 - 12:00; Viernes 13:00 - 14:00 | Bloque: BIOBLO6 | Programa: BIO
# Profesor: VIDAL - FLORES ANA MARIA DEL RAYO | Materia: Investigación para la Arquitec | Aula: 303 (Edificio EMA6) | Horarios: Lunes 08:00 - 09:00; Miércoles 09:00 - 10:00; Viernes 11:00 - 12:00 | Bloque: ARQBLO5 | Programa: ARQ
# Profesor: VIDAL - FLORES ANA MARIA DEL RAYO | Materia: Dibujo I | Aula: 301 (Edificio EMA6) | Horarios: Lunes 10:00 - 11:00; Lunes 17:00 - 18:00; Martes 15:00 - 16:00; Miércoles 12:00 - 13:00 | Bloque: ARQBLO5 | Programa: ARQ
# Profesor: VIDAL - FLORES ANA MARIA DEL RAYO | Materia: Investigación para la Arquitec | Aula: 106 (Edificio EMA5) | Horarios: Lunes 12:00 - 13:00; Lunes 16:00 - 17:00; Viernes 09:00 - 10:00 | Bloque: ARQBLO7 | Programa: ARQ
# Profesor: VIDAL - FLORES ANA MARIA DEL RAYO | Materia: Dibujo I | Aula: 104 (Edificio EMA7) | Horarios: Lunes 14:00 - 15:00; Martes 09:00 - 11:00; Miércoles 11:00 - 12:00 | Bloque: ARQBLO10 | Programa: ARQ
# Profesor: MALDONADO - SANCHEZ PABLO | Materia: Dibujo I | Aula: 205 (Edificio EMA7) | Horarios: Jueves 09:00 - 11:00; Jueves 16:00 - 17:00; Viernes 17:00 - 18:00 | Bloque: ARQBLO1 | Programa: ARQ
# Profesor: MALDONADO - SANCHEZ PABLO | Materia: Taller de Diseño Básico | Aula: 202 (Edificio EMA6) | Horarios: Lunes 13:00 - 14:00; Martes 15:00 - 16:00; Miércoles 12:00 - 13:00; Miércoles 14:00 - 15:00; Miércoles 17:00 - 18:00; Viernes 12:00 - 13:00 | Bloque: ARQBLO1 | Programa: ARQ
# Profesor: MALDONADO - SANCHEZ PABLO | Materia: Investigación para la Arquitec | Aula: 204 (Edificio EMA6) | Horarios: Martes 13:00 - 14:00; Jueves 12:00 - 14:00 | Bloque: ARQBLO3 | Programa: ARQ
# Profesor: MALDONADO - SANCHEZ PABLO | Materia: Teoría de la Arquitectura | Aula: 103 (Edificio EMA5) | Horarios: Martes 16:00 - 17:00; Jueves 11:00 - 12:00; Jueves 14:00 - 15:00 | Bloque: ARQBLO7 | Programa: ARQ
# Profesor: MALDONADO - SANCHEZ PABLO | Materia: Investigación para la Arquitec | Aula: 108 (Edificio EMA6) | Horarios: Martes 12:00 - 13:00; Miércoles 09:00 - 10:00; Viernes 08:00 - 09:00 | Bloque: ARQBLO8 | Programa: ARQ
# Profesor: MALDONADO - SANCHEZ PABLO | Materia: Teoría de la Arquitectura | Aula: 305 (Edificio EMA6) | Horarios: Martes 08:00 - 09:00; Martes 14:00 - 15:00; Miércoles 08:00 - 09:00 | Bloque: ARQBLO10 | Programa: ARQ
# Profesor: MENDOZA - DIAZ LUIS FELIPE | Materia: Hist. y Tendencias Urbano Arq. | Aula: 303 (Edificio EMA7) | Horarios: Lunes 08:00 - 09:00; Lunes 16:00 - 17:00; Jueves 11:00 - 12:00 | Bloque: ARQBLO2 | Programa: ARQ
# Profesor: MENDOZA - DIAZ LUIS FELIPE | Materia: Hist. y Tendencias Urbano Arq. | Aula: 108 (Edificio EMA5) | Horarios: Lunes 11:00 - 12:00; Miércoles 09:00 - 10:00; Miércoles 16:00 - 17:00 | Bloque: ARQBLO3 | Programa: ARQ
# Profesor: MENDOZA - DIAZ LUIS FELIPE | Materia: Hist. y Tendencias Urbano Arq. | Aula: 301 (Edificio EMA7) | Horarios: Jueves 08:00 - 09:00; Viernes 08:00 - 09:00; Viernes 17:00 - 18:00 | Bloque: ARQBLO4 | Programa: ARQ
# Profesor: MENDOZA - DIAZ LUIS FELIPE | Materia: Geometría Descriptiva | Aula: 202 (Edificio EMA5) | Horarios: Martes 10:00 - 11:00; Miércoles 08:00 - 09:00; Miércoles 13:00 - 14:00; Jueves 09:00 - 10:00 | Bloque: ARQBLO5 | Programa: ARQ
# Profesor: MENDOZA - DIAZ LUIS FELIPE | Materia: Hist. y Tendencias Urbano Arq. | Aula: 301 (Edificio EMA7) | Horarios: Lunes 12:00 - 13:00; Martes 13:00 - 14:00; Viernes 14:00 - 15:00 | Bloque: ARQBLO7 | Programa: ARQ
# Profesor: MENDOZA - DIAZ LUIS FELIPE | Materia: Geometría Descriptiva | Aula: 305 (Edificio EMA6) | Horarios: Lunes 14:00 - 15:00; Martes 16:00 - 17:00; Miércoles 12:00 - 13:00; Jueves 12:00 - 13:00 | Bloque: ARQBLO9 | Programa: ARQ
# Profesor: MENDOZA - DIAZ LUIS FELIPE | Materia: Geometría Descriptiva | Aula: 201 (Edificio EMA5) | Horarios: Martes 09:00 - 10:00; Martes 11:00 - 12:00; Miércoles 15:00 - 16:00; Jueves 16:00 - 17:00 | Bloque: ARQBLO10 | Programa: ARQ
# Profesor: BARCEINAS - CANO ERIC | Materia: Hist. y Tendencias Urbano Arq. | Aula: 307 (Edificio EMA5) | Horarios: Lunes 15:00 - 16:00; Jueves 09:00 - 10:00; Viernes 15:00 - 16:00 | Bloque: ARQBLO9 | Programa: ARQ
# Profesor: DE LA TORRE - SANCHEZ CHRISTIAN ENRIQUE | Materia: Teoría de la Arquitectura | Aula: 105 (Edificio EMA5) | Horarios: Lunes 10:00 - 11:00; Viernes 14:00 - 15:00; Viernes 16:00 - 17:00 | Bloque: ARQBLO5 | Programa: ARQ
# Profesor: CRUZ - MERIDA JORGE ALEJANDRO | Materia: Quimica General | Aula: 209 (Edificio EMA6) | Horarios: Lunes 11:00 - 12:00; Martes 10:00 - 11:00; Martes 14:00 - 15:00; Miércoles 10:00 - 11:00; Miércoles 14:00 - 15:00; Miércoles 16:00 - 17:00; Viernes 10:00 - 11:00 | Bloque: BIOBLO7 | Programa: BIO
# Profesor: VERGARA - JUAREZ ENRIQUE | Materia: Taller de Diseño Básico | Aula: 204 (Edificio EMA6) | Horarios: Lunes 09:00 - 10:00; Lunes 14:00 - 15:00; Lunes 16:00 - 18:00; Martes 10:00 - 11:00; Jueves 15:00 - 16:00 | Bloque: ARQBLO2 | Programa: ARQ
# Profesor: VERGARA - JUAREZ ENRIQUE | Materia: Taller de Diseño Básico | Aula: 106 (Edificio EMA5) | Horarios: Martes 13:00 - 14:00; Miércoles 15:00 - 16:00; Jueves 08:00 - 09:00; Viernes 08:00 - 09:00; Viernes 12:00 - 14:00 | Bloque: ARQBLO3 | Programa: ARQ
# Profesor: VERGARA - JUAREZ ENRIQUE | Materia: Teoría de la Arquitectura | Aula: 209 (Edificio EMA5) | Horarios: Miércoles 11:00 - 12:00; Miércoles 13:00 - 14:00; Jueves 16:00 - 17:00 | Bloque: ARQBLO4 | Programa: ARQ
# Profesor: VERGARA - JUAREZ ENRIQUE | Materia: Taller de Diseño Básico | Aula: 209 (Edificio EMA7) | Horarios: Martes 08:00 - 09:00; Martes 17:00 - 18:00; Miércoles 08:00 - 09:00; Miércoles 12:00 - 13:00; Viernes 09:00 - 10:00; Viernes 11:00 - 12:00 | Bloque: ARQBLO7 | Programa: ARQ
# Profesor: VERGARA - JUAREZ ENRIQUE | Materia: Hist. y Tendencias Urbano Arq. | Aula: 209 (Edificio EMA7) | Horarios: Miércoles 10:00 - 11:00; Miércoles 17:00 - 18:00; Viernes 14:00 - 15:00 | Bloque: ARQBLO8 | Programa: ARQ
# Profesor: VERGARA - JUAREZ ENRIQUE | Materia: Teoría de la Arquitectura | Aula: 307 (Edificio EMA5) | Horarios: Martes 14:00 - 16:00; Jueves 13:00 - 14:00 | Bloque: ARQBLO9 | Programa: ARQ
# Profesor: REYES - ROMERO MARIBEL | Materia: Biomatematicas I | Aula: 205 (Edificio EMA7) | Horarios: Lunes 10:00 - 11:00; Lunes 13:00 - 14:00; Martes 16:00 - 17:00; Miércoles 10:00 - 11:00; Jueves 08:00 - 09:00; Jueves 13:00 - 14:00; Viernes 14:00 - 15:00 | Bloque: BIOBLO1 | Programa: BIO
# Profesor: REYES - ROMERO MARIBEL | Materia: Biomatematicas I | Aula: 203 (Edificio EMA7) | Horarios: Martes 10:00 - 11:00; Martes 13:00 - 14:00; Miércoles 12:00 - 13:00; Miércoles 14:00 - 15:00; Miércoles 17:00 - 18:00; Viernes 09:00 - 10:00; Viernes 15:00 - 16:00 | Bloque: BIOBLO4 | Programa: BIO
# Profesor: REYES - ROMERO MARIBEL | Materia: Biomatematicas I | Aula: 108 (Edificio EMA7) | Horarios: Lunes 11:00 - 12:00; Lunes 16:00 - 17:00; Martes 08:00 - 10:00; Miércoles 11:00 - 12:00; Miércoles 16:00 - 17:00; Jueves 17:00 - 18:00 | Bloque: BIOBLO7 | Programa: BIO
# Profesor: MORALES - ORTEGA JOSE ALEJANDRO | Materia: Taller de Diseño Básico | Aula: 103 (Edificio EMA7) | Horarios: Lunes 17:00 - 18:00; Martes 10:00 - 11:00; Martes 12:00 - 13:00; Miércoles 15:00 - 16:00; Jueves 16:00 - 17:00; Viernes 13:00 - 14:00 | Bloque: ARQBLO9 | Programa: ARQ
# Profesor: MORALES - ORTEGA JOSE ALEJANDRO | Materia: Taller de Diseño Básico | Aula: 201 (Edificio EMA5) | Horarios: Lunes 08:00 - 09:00; Lunes 10:00 - 11:00; Lunes 16:00 - 17:00; Martes 08:00 - 09:00; Jueves 15:00 - 16:00; Viernes 17:00 - 18:00 | Bloque: ARQBLO10 | Programa: ARQ
# Profesor: VAZQUEZ - GOMEZ NOEMI ZAHIRA | Materia: Taller de Diseño Básico | Aula: 307 (Edificio EMA7) | Horarios: Lunes 13:00 - 14:00; Martes 14:00 - 15:00; Jueves 08:00 - 09:00; Jueves 12:00 - 13:00; Jueves 16:00 - 17:00; Viernes 16:00 - 17:00 | Bloque: ARQBLO4 | Programa: ARQ
# Profesor: VAZQUEZ - GOMEZ NOEMI ZAHIRA | Materia: Taller de Diseño Básico | Aula: 104 (Edificio EMA7) | Horarios: Lunes 09:00 - 10:00; Lunes 11:00 - 12:00; Lunes 15:00 - 16:00; Martes 08:00 - 09:00; Jueves 11:00 - 12:00; Viernes 15:00 - 16:00 | Bloque: ARQBLO6 | Programa: ARQ
# Profesor: DE ANDA - REYES MARIA EUNICE | Materia: Quimica General | Aula: 205 (Edificio EMA7) | Horarios: Martes 11:00 - 13:00; Miércoles 11:00 - 12:00; Jueves 14:00 - 15:00; Jueves 17:00 - 18:00; Viernes 09:00 - 10:00; Viernes 15:00 - 16:00 | Bloque: BIOBLO5 | Programa: BIO
# Profesor: SANTIBAÑEZ - AGUASCALIENTES NORMA ANGELICA | Materia: Quimica General | Aula: 103 (Edificio EMA7) | Horarios: Lunes 09:00 - 10:00; Martes 16:00 - 17:00; Miércoles 17:00 - 18:00; Jueves 13:00 - 14:00; Jueves 15:00 - 16:00; Viernes 09:00 - 11:00 | Bloque: BIOBLO1 | Programa: BIO
# Profesor: SANTIBAÑEZ - AGUASCALIENTES NORMA ANGELICA | Materia: Quimica General | Aula: 305 (Edificio EMA6) | Horarios: Lunes 08:00 - 09:00; Martes 11:00 - 13:00; Miércoles 11:00 - 12:00; Miércoles 15:00 - 16:00; Viernes 08:00 - 09:00; Viernes 14:00 - 15:00 | Bloque: BIOBLO2 | Programa: BIO
# Profesor: SANTIBAÑEZ - AGUASCALIENTES NORMA ANGELICA | Materia: Quimica General | Aula: 106 (Edificio EMA6) | Horarios: Martes 08:00 - 10:00; Martes 15:00 - 16:00; Miércoles 13:00 - 15:00; Jueves 10:00 - 11:00; Viernes 17:00 - 18:00 | Bloque: BIOBLO3 | Programa: BIO
# Profesor: SANTIBAÑEZ - AGUASCALIENTES NORMA ANGELICA | Materia: Quimica General | Aula: 204 (Edificio EMA6) | Horarios: Lunes 13:00 - 14:00; Lunes 15:00 - 16:00; Miércoles 09:00 - 10:00; Miércoles 16:00 - 17:00; Jueves 09:00 - 10:00; Viernes 15:00 - 17:00 | Bloque: BIOBLO4 | Programa: BIO
# Profesor: SANTIBAÑEZ - AGUASCALIENTES NORMA ANGELICA | Materia: Quimica General | Aula: 306 (Edificio EMA5) | Horarios: Lunes 11:00 - 12:00; Lunes 16:00 - 17:00; Martes 14:00 - 15:00; Martes 17:00 - 18:00; Jueves 08:00 - 09:00; Jueves 14:00 - 15:00; Viernes 13:00 - 14:00 | Bloque: BIOBLO6 | Programa: BIO
# Profesor: GALINDO - ORTIZ JESSICA | Materia: Hist. y Tendencias Urbano Arq. | Aula: 205 (Edificio EMA6) | Horarios: Miércoles 11:00 - 12:00; Miércoles 15:00 - 16:00; Jueves 15:00 - 16:00 | Bloque: ARQBLO6 | Programa: ARQ
#
# Archivo 'asignaciones.xlsx' creado con éxito.
#
# 📘 Horarios agrupados por Bloque y Programa:
#
# ======================================================================
# 🔹 BLOQUE: ARQBLO1 | PROGRAMA EDUCATIVO: ARQ
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        08:00 - 09:00   Investigación para la Arquitec      OCHOA - BILBAO IGNACIO         208        EMA6
# Lunes        09:00 - 10:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  105        EMA5
# Lunes        13:00 - 14:00   Taller de Diseño Básico             MALDONADO - SANCHEZ PABLO      202        EMA6
# Martes       09:00 - 10:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  105        EMA5
# Martes       14:00 - 15:00   Hist. y Tendencias Urbano Arq.      ALONSO - PEREZ CARLOS          302        EMA6
# Martes       15:00 - 16:00   Taller de Diseño Básico             MALDONADO - SANCHEZ PABLO      202        EMA6
# Miércoles    09:00 - 10:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  105        EMA5
# Miércoles    12:00 - 13:00   Taller de Diseño Básico             MALDONADO - SANCHEZ PABLO      202        EMA6
# Miércoles    14:00 - 15:00   Taller de Diseño Básico             MALDONADO - SANCHEZ PABLO      202        EMA6
# Miércoles    15:00 - 16:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  105        EMA5
# Miércoles    17:00 - 18:00   Taller de Diseño Básico             MALDONADO - SANCHEZ PABLO      202        EMA6
# Jueves       09:00 - 11:00   Dibujo I                            MALDONADO - SANCHEZ PABLO      205        EMA7
# Jueves       10:00 - 11:00   Teoría de la Arquitectura           GARCIA - SALAZAR RUBEN         206        EMA5
# Jueves       16:00 - 17:00   Teoría de la Arquitectura           GARCIA - SALAZAR RUBEN         206        EMA5
# Jueves       16:00 - 17:00   Dibujo I                            MALDONADO - SANCHEZ PABLO      205        EMA7
# Jueves       17:00 - 18:00   Matem. para la Arquitectura I       JAEN - VARGAS MARIA GUADALUPE  205        EMA6
# Jueves       17:00 - 18:00   Investigación para la Arquitec      OCHOA - BILBAO IGNACIO         208        EMA6
# Viernes      08:00 - 09:00   Hist. y Tendencias Urbano Arq.      ALONSO - PEREZ CARLOS          302        EMA6
# Viernes      10:00 - 12:00   Matem. para la Arquitectura I       JAEN - VARGAS MARIA GUADALUPE  205        EMA6
# Viernes      11:00 - 12:00   Hist. y Tendencias Urbano Arq.      ALONSO - PEREZ CARLOS          302        EMA6
# Viernes      11:00 - 12:00   Investigación para la Arquitec      OCHOA - BILBAO IGNACIO         208        EMA6
# Viernes      12:00 - 13:00   Taller de Diseño Básico             MALDONADO - SANCHEZ PABLO      202        EMA6
# Viernes      15:00 - 16:00   Teoría de la Arquitectura           GARCIA - SALAZAR RUBEN         206        EMA5
# Viernes      17:00 - 18:00   Matem. para la Arquitectura I       JAEN - VARGAS MARIA GUADALUPE  205        EMA6
# Viernes      17:00 - 18:00   Dibujo I                            MALDONADO - SANCHEZ PABLO      205        EMA7
#
# ======================================================================
# 🔹 BLOQUE: ARQBLO10 | PROGRAMA EDUCATIVO: ARQ
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        08:00 - 09:00   Taller de Diseño Básico             MORALES - ORTEGA JOSE ALEJAND  201        EMA5
# Lunes        10:00 - 11:00   Taller de Diseño Básico             MORALES - ORTEGA JOSE ALEJAND  201        EMA5
# Lunes        14:00 - 15:00   Dibujo I                            VIDAL - FLORES ANA MARIA DEL   104        EMA7
# Lunes        14:00 - 16:00   Matem. para la Arquitectura I       CUAPA - CANTO ROSALBA          305        EMA7
# Lunes        16:00 - 17:00   Taller de Diseño Básico             MORALES - ORTEGA JOSE ALEJAND  201        EMA5
# Martes       08:00 - 09:00   Hist. y Tendencias Urbano Arq.      ALONSO - PEREZ CARLOS          104        EMA5
# Martes       08:00 - 09:00   Teoría de la Arquitectura           MALDONADO - SANCHEZ PABLO      305        EMA6
# Martes       08:00 - 09:00   Taller de Diseño Básico             MORALES - ORTEGA JOSE ALEJAND  201        EMA5
# Martes       09:00 - 10:00   Geometría Descriptiva               MENDOZA - DIAZ LUIS FELIPE     201        EMA5
# Martes       09:00 - 11:00   Dibujo I                            VIDAL - FLORES ANA MARIA DEL   104        EMA7
# Martes       11:00 - 12:00   Geometría Descriptiva               MENDOZA - DIAZ LUIS FELIPE     201        EMA5
# Martes       14:00 - 15:00   Teoría de la Arquitectura           MALDONADO - SANCHEZ PABLO      305        EMA6
# Martes       15:00 - 16:00   Matem. para la Arquitectura I       CUAPA - CANTO ROSALBA          305        EMA7
# Miércoles    08:00 - 09:00   Teoría de la Arquitectura           MALDONADO - SANCHEZ PABLO      305        EMA6
# Miércoles    09:00 - 10:00   Investigación para la Arquitec      AGUILAR - TRONCOZO CHRISTIAN   307        EMA7
# Miércoles    09:00 - 11:00   Hist. y Tendencias Urbano Arq.      ALONSO - PEREZ CARLOS          104        EMA5
# Miércoles    11:00 - 12:00   Dibujo I                            VIDAL - FLORES ANA MARIA DEL   104        EMA7
# Miércoles    14:00 - 15:00   Investigación para la Arquitec      AGUILAR - TRONCOZO CHRISTIAN   307        EMA7
# Miércoles    15:00 - 16:00   Geometría Descriptiva               MENDOZA - DIAZ LUIS FELIPE     201        EMA5
# Miércoles    16:00 - 17:00   Investigación para la Arquitec      AGUILAR - TRONCOZO CHRISTIAN   307        EMA7
# Miércoles    17:00 - 18:00   Matem. para la Arquitectura I       CUAPA - CANTO ROSALBA          305        EMA7
# Jueves       15:00 - 16:00   Taller de Diseño Básico             MORALES - ORTEGA JOSE ALEJAND  201        EMA5
# Jueves       16:00 - 17:00   Geometría Descriptiva               MENDOZA - DIAZ LUIS FELIPE     201        EMA5
# Viernes      17:00 - 18:00   Taller de Diseño Básico             MORALES - ORTEGA JOSE ALEJAND  201        EMA5
#
# ======================================================================
# 🔹 BLOQUE: ARQBLO2 | PROGRAMA EDUCATIVO: ARQ
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        08:00 - 09:00   Hist. y Tendencias Urbano Arq.      MENDOZA - DIAZ LUIS FELIPE     303        EMA7
# Lunes        09:00 - 10:00   Taller de Diseño Básico             VERGARA - JUAREZ ENRIQUE       204        EMA6
# Lunes        14:00 - 15:00   Taller de Diseño Básico             VERGARA - JUAREZ ENRIQUE       204        EMA6
# Lunes        15:00 - 16:00   Investigación para la Arquitec      AGUILAR - TRONCOZO CHRISTIAN   306        EMA5
# Lunes        16:00 - 17:00   Dibujo I                            MALDONADO - CASTRO NAHELY      105        EMA5
# Lunes        16:00 - 17:00   Hist. y Tendencias Urbano Arq.      MENDOZA - DIAZ LUIS FELIPE     303        EMA7
# Lunes        16:00 - 18:00   Taller de Diseño Básico             VERGARA - JUAREZ ENRIQUE       204        EMA6
# Lunes        17:00 - 18:00   Investigación para la Arquitec      AGUILAR - TRONCOZO CHRISTIAN   306        EMA5
# Lunes        17:00 - 18:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  206        EMA6
# Martes       08:00 - 09:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  206        EMA6
# Martes       10:00 - 11:00   Taller de Diseño Básico             VERGARA - JUAREZ ENRIQUE       204        EMA6
# Martes       12:00 - 13:00   Dibujo I                            MALDONADO - CASTRO NAHELY      105        EMA5
# Martes       13:00 - 14:00   Matem. para la Arquitectura I       CUAPA - CANTO ROSALBA          102        EMA6
# Martes       17:00 - 18:00   Teoría de la Arquitectura           GARCIA - SALAZAR RUBEN         204        EMA5
# Miércoles    09:00 - 10:00   Teoría de la Arquitectura           GARCIA - SALAZAR RUBEN         204        EMA5
# Miércoles    09:00 - 10:00   Matem. para la Arquitectura I       CUAPA - CANTO ROSALBA          102        EMA6
# Miércoles    14:00 - 15:00   Dibujo I                            MALDONADO - CASTRO NAHELY      105        EMA5
# Jueves       11:00 - 12:00   Dibujo I                            MALDONADO - CASTRO NAHELY      105        EMA5
# Jueves       11:00 - 12:00   Hist. y Tendencias Urbano Arq.      MENDOZA - DIAZ LUIS FELIPE     303        EMA7
# Jueves       12:00 - 13:00   Matem. para la Arquitectura I       CUAPA - CANTO ROSALBA          102        EMA6
# Jueves       15:00 - 16:00   Teoría de la Arquitectura           GARCIA - SALAZAR RUBEN         204        EMA5
# Jueves       15:00 - 16:00   Investigación para la Arquitec      AGUILAR - TRONCOZO CHRISTIAN   306        EMA5
# Jueves       15:00 - 16:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  206        EMA6
# Jueves       15:00 - 16:00   Taller de Diseño Básico             VERGARA - JUAREZ ENRIQUE       204        EMA6
# Viernes      09:00 - 10:00   Matem. para la Arquitectura I       CUAPA - CANTO ROSALBA          102        EMA6
# Viernes      13:00 - 14:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  206        EMA6
#
# ======================================================================
# 🔹 BLOQUE: ARQBLO3 | PROGRAMA EDUCATIVO: ARQ
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        11:00 - 12:00   Hist. y Tendencias Urbano Arq.      MENDOZA - DIAZ LUIS FELIPE     108        EMA5
# Martes       09:00 - 10:00   Teoría de la Arquitectura           OCHOA - BILBAO IGNACIO         202        EMA6
# Martes       10:00 - 11:00   Matem. para la Arquitectura I       MORA - RODRIGUEZ DAVID         103        EMA6
# Martes       13:00 - 14:00   Matem. para la Arquitectura I       MORA - RODRIGUEZ DAVID         103        EMA6
# Martes       13:00 - 14:00   Investigación para la Arquitec      MALDONADO - SANCHEZ PABLO      204        EMA6
# Martes       13:00 - 14:00   Taller de Diseño Básico             VERGARA - JUAREZ ENRIQUE       106        EMA5
# Martes       15:00 - 16:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  107        EMA6
# Martes       15:00 - 17:00   Dibujo I                            ALONSO - PEREZ CARLOS          107        EMA5
# Miércoles    09:00 - 10:00   Teoría de la Arquitectura           OCHOA - BILBAO IGNACIO         202        EMA6
# Miércoles    09:00 - 10:00   Hist. y Tendencias Urbano Arq.      MENDOZA - DIAZ LUIS FELIPE     108        EMA5
# Miércoles    15:00 - 16:00   Taller de Diseño Básico             VERGARA - JUAREZ ENRIQUE       106        EMA5
# Miércoles    16:00 - 17:00   Hist. y Tendencias Urbano Arq.      MENDOZA - DIAZ LUIS FELIPE     108        EMA5
# Jueves       08:00 - 09:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  107        EMA6
# Jueves       08:00 - 09:00   Matem. para la Arquitectura I       MORA - RODRIGUEZ DAVID         103        EMA6
# Jueves       08:00 - 09:00   Taller de Diseño Básico             VERGARA - JUAREZ ENRIQUE       106        EMA5
# Jueves       11:00 - 12:00   Dibujo I                            ALONSO - PEREZ CARLOS          107        EMA5
# Jueves       12:00 - 14:00   Investigación para la Arquitec      MALDONADO - SANCHEZ PABLO      204        EMA6
# Jueves       14:00 - 15:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  107        EMA6
# Jueves       16:00 - 17:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  107        EMA6
# Viernes      08:00 - 09:00   Taller de Diseño Básico             VERGARA - JUAREZ ENRIQUE       106        EMA5
# Viernes      09:00 - 10:00   Teoría de la Arquitectura           OCHOA - BILBAO IGNACIO         202        EMA6
# Viernes      11:00 - 12:00   Matem. para la Arquitectura I       MORA - RODRIGUEZ DAVID         103        EMA6
# Viernes      12:00 - 13:00   Dibujo I                            ALONSO - PEREZ CARLOS          107        EMA5
# Viernes      12:00 - 14:00   Taller de Diseño Básico             VERGARA - JUAREZ ENRIQUE       106        EMA5
#
# ======================================================================
# 🔹 BLOQUE: ARQBLO4 | PROGRAMA EDUCATIVO: ARQ
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        10:00 - 11:00   Dibujo I                            ROSAS - LORANCA ROBERTO        103        EMA7
# Lunes        11:00 - 12:00   Matem. para la Arquitectura I       JAEN - VARGAS MARIA GUADALUPE  107        EMA5
# Lunes        13:00 - 14:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   307        EMA7
# Lunes        15:00 - 16:00   Matem. para la Arquitectura I       JAEN - VARGAS MARIA GUADALUPE  107        EMA5
# Martes       09:00 - 10:00   Dibujo I                            ROSAS - LORANCA ROBERTO        103        EMA7
# Martes       14:00 - 15:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  106        EMA6
# Martes       14:00 - 15:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   307        EMA7
# Martes       17:00 - 18:00   Matem. para la Arquitectura I       JAEN - VARGAS MARIA GUADALUPE  107        EMA5
# Martes       17:00 - 18:00   Investigación para la Arquitec      MALDONADO - CASTRO NAHELY      306        EMA6
# Miércoles    08:00 - 09:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  106        EMA6
# Miércoles    11:00 - 12:00   Teoría de la Arquitectura           VERGARA - JUAREZ ENRIQUE       209        EMA5
# Miércoles    13:00 - 14:00   Investigación para la Arquitec      MALDONADO - CASTRO NAHELY      306        EMA6
# Miércoles    13:00 - 14:00   Teoría de la Arquitectura           VERGARA - JUAREZ ENRIQUE       209        EMA5
# Miércoles    17:00 - 18:00   Matem. para la Arquitectura I       JAEN - VARGAS MARIA GUADALUPE  107        EMA5
# Jueves       08:00 - 09:00   Hist. y Tendencias Urbano Arq.      MENDOZA - DIAZ LUIS FELIPE     301        EMA7
# Jueves       08:00 - 09:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   307        EMA7
# Jueves       09:00 - 10:00   Dibujo I                            ROSAS - LORANCA ROBERTO        103        EMA7
# Jueves       11:00 - 12:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  106        EMA6
# Jueves       12:00 - 13:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   307        EMA7
# Jueves       16:00 - 17:00   Teoría de la Arquitectura           VERGARA - JUAREZ ENRIQUE       209        EMA5
# Jueves       16:00 - 17:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   307        EMA7
# Viernes      08:00 - 09:00   Hist. y Tendencias Urbano Arq.      MENDOZA - DIAZ LUIS FELIPE     301        EMA7
# Viernes      12:00 - 13:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  106        EMA6
# Viernes      15:00 - 16:00   Dibujo I                            ROSAS - LORANCA ROBERTO        103        EMA7
# Viernes      16:00 - 17:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   307        EMA7
# Viernes      17:00 - 18:00   Investigación para la Arquitec      MALDONADO - CASTRO NAHELY      306        EMA6
# Viernes      17:00 - 18:00   Hist. y Tendencias Urbano Arq.      MENDOZA - DIAZ LUIS FELIPE     301        EMA7
#
# ======================================================================
# 🔹 BLOQUE: ARQBLO5 | PROGRAMA EDUCATIVO: ARQ
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        08:00 - 09:00   Taller de Diseño Básico             ROSAS - LORANCA ROBERTO        204        EMA6
# Lunes        08:00 - 09:00   Matem. para la Arquitectura I       MALDONADO - CASTRO NAHELY      107        EMA7
# Lunes        08:00 - 09:00   Investigación para la Arquitec      VIDAL - FLORES ANA MARIA DEL   303        EMA6
# Lunes        10:00 - 11:00   Dibujo I                            VIDAL - FLORES ANA MARIA DEL   301        EMA6
# Lunes        10:00 - 11:00   Teoría de la Arquitectura           DE LA TORRE - SANCHEZ CHRISTI  105        EMA5
# Lunes        12:00 - 13:00   Matem. para la Arquitectura I       MALDONADO - CASTRO NAHELY      107        EMA7
# Lunes        17:00 - 18:00   Dibujo I                            VIDAL - FLORES ANA MARIA DEL   301        EMA6
# Martes       10:00 - 11:00   Matem. para la Arquitectura I       MALDONADO - CASTRO NAHELY      107        EMA7
# Martes       10:00 - 11:00   Geometría Descriptiva               MENDOZA - DIAZ LUIS FELIPE     202        EMA5
# Martes       15:00 - 16:00   Dibujo I                            VIDAL - FLORES ANA MARIA DEL   301        EMA6
# Miércoles    08:00 - 09:00   Geometría Descriptiva               MENDOZA - DIAZ LUIS FELIPE     202        EMA5
# Miércoles    09:00 - 10:00   Matem. para la Arquitectura I       MALDONADO - CASTRO NAHELY      107        EMA7
# Miércoles    09:00 - 10:00   Investigación para la Arquitec      VIDAL - FLORES ANA MARIA DEL   303        EMA6
# Miércoles    10:00 - 11:00   Taller de Diseño Básico             ROSAS - LORANCA ROBERTO        204        EMA6
# Miércoles    12:00 - 13:00   Dibujo I                            VIDAL - FLORES ANA MARIA DEL   301        EMA6
# Miércoles    13:00 - 14:00   Hist. y Tendencias Urbano Arq.      ALONSO - PEREZ CARLOS          303        EMA6
# Miércoles    13:00 - 14:00   Geometría Descriptiva               MENDOZA - DIAZ LUIS FELIPE     202        EMA5
# Jueves       09:00 - 10:00   Geometría Descriptiva               MENDOZA - DIAZ LUIS FELIPE     202        EMA5
# Jueves       10:00 - 11:00   Hist. y Tendencias Urbano Arq.      ALONSO - PEREZ CARLOS          303        EMA6
# Jueves       11:00 - 12:00   Taller de Diseño Básico             ROSAS - LORANCA ROBERTO        204        EMA6
# Viernes      10:00 - 11:00   Hist. y Tendencias Urbano Arq.      ALONSO - PEREZ CARLOS          303        EMA6
# Viernes      11:00 - 12:00   Investigación para la Arquitec      VIDAL - FLORES ANA MARIA DEL   303        EMA6
# Viernes      12:00 - 15:00   Taller de Diseño Básico             ROSAS - LORANCA ROBERTO        204        EMA6
# Viernes      14:00 - 15:00   Teoría de la Arquitectura           DE LA TORRE - SANCHEZ CHRISTI  105        EMA5
# Viernes      16:00 - 17:00   Teoría de la Arquitectura           DE LA TORRE - SANCHEZ CHRISTI  105        EMA5
#
# ======================================================================
# 🔹 BLOQUE: ARQBLO6 | PROGRAMA EDUCATIVO: ARQ
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        09:00 - 10:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   104        EMA7
# Lunes        11:00 - 12:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   104        EMA7
# Lunes        12:00 - 13:00   Investigación para la Arquitec      RAMIREZ - MENDOZA MARCELINO    104        EMA7
# Lunes        12:00 - 13:00   Dibujo I                            ALONSO - PEREZ CARLOS          302        EMA6
# Lunes        15:00 - 16:00   Matem. para la Arquitectura I       MALDONADO - CASTRO NAHELY      208        EMA7
# Lunes        15:00 - 16:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   104        EMA7
# Martes       08:00 - 09:00   Teoría de la Arquitectura           MALDONADO - CASTRO NAHELY      203        EMA6
# Martes       08:00 - 09:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   104        EMA7
# Martes       10:00 - 11:00   Dibujo I                            ALONSO - PEREZ CARLOS          302        EMA6
# Martes       12:00 - 13:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  206        EMA6
# Martes       14:00 - 15:00   Investigación para la Arquitec      RAMIREZ - MENDOZA MARCELINO    104        EMA7
# Miércoles    08:00 - 09:00   Matem. para la Arquitectura I       MALDONADO - CASTRO NAHELY      208        EMA7
# Miércoles    10:00 - 11:00   Matem. para la Arquitectura I       MALDONADO - CASTRO NAHELY      208        EMA7
# Miércoles    11:00 - 12:00   Hist. y Tendencias Urbano Arq.      GALINDO - ORTIZ JESSICA        205        EMA6
# Miércoles    14:00 - 15:00   Investigación para la Arquitec      RAMIREZ - MENDOZA MARCELINO    104        EMA7
# Miércoles    14:00 - 15:00   Dibujo I                            ALONSO - PEREZ CARLOS          302        EMA6
# Miércoles    15:00 - 16:00   Hist. y Tendencias Urbano Arq.      GALINDO - ORTIZ JESSICA        205        EMA6
# Miércoles    16:00 - 17:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  206        EMA6
# Jueves       08:00 - 09:00   Dibujo I                            ALONSO - PEREZ CARLOS          302        EMA6
# Jueves       11:00 - 12:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   104        EMA7
# Jueves       15:00 - 16:00   Teoría de la Arquitectura           MALDONADO - CASTRO NAHELY      203        EMA6
# Jueves       15:00 - 16:00   Hist. y Tendencias Urbano Arq.      GALINDO - ORTIZ JESSICA        205        EMA6
# Jueves       16:00 - 17:00   Matem. para la Arquitectura I       MALDONADO - CASTRO NAHELY      208        EMA7
# Viernes      09:00 - 10:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  206        EMA6
# Viernes      14:00 - 15:00   Geometría Descriptiva               JAEN - VARGAS MARIA GUADALUPE  206        EMA6
# Viernes      14:00 - 15:00   Teoría de la Arquitectura           MALDONADO - CASTRO NAHELY      203        EMA6
# Viernes      15:00 - 16:00   Taller de Diseño Básico             VAZQUEZ - GOMEZ NOEMI ZAHIRA   104        EMA7
#
# ======================================================================
# 🔹 BLOQUE: ARQBLO7 | PROGRAMA EDUCATIVO: ARQ
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        09:00 - 10:00   Dibujo I                            ROSAS - LORANCA ROBERTO        303        EMA5
# Lunes        12:00 - 13:00   Investigación para la Arquitec      VIDAL - FLORES ANA MARIA DEL   106        EMA5
# ...
# Lunes        11:00 - 12:00   Introduccion a la Biologia          DIAZ - CARRANZA GUADALUPE      303        EMA6
# Lunes        13:00 - 14:00   Biomatematicas I                    REYES - ROMERO MARIBEL         205        EMA7
# Lunes        17:00 - 18:00   Introduccion a la Biologia          DIAZ - CARRANZA GUADALUPE      303        EMA6
# Martes       16:00 - 17:00   Biomatematicas I                    REYES - ROMERO MARIBEL         205        EMA7
# Martes       16:00 - 17:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  103        EMA7
# Miércoles    10:00 - 11:00   Biomatematicas I                    REYES - ROMERO MARIBEL         205        EMA7
# Miércoles    17:00 - 18:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  103        EMA7
# Jueves       08:00 - 09:00   Biomatematicas I                    REYES - ROMERO MARIBEL         205        EMA7
# Jueves       11:00 - 12:00   Introduccion a la Biologia          DIAZ - CARRANZA GUADALUPE      303        EMA6
# Jueves       13:00 - 14:00   Introduccion a la Biologia          DIAZ - CARRANZA GUADALUPE      303        EMA6
# Jueves       13:00 - 14:00   Biomatematicas I                    REYES - ROMERO MARIBEL         205        EMA7
# Jueves       13:00 - 14:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  103        EMA7
# Jueves       15:00 - 16:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  103        EMA7
# Viernes      09:00 - 11:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  103        EMA7
# Viernes      14:00 - 15:00   Biomatematicas I                    REYES - ROMERO MARIBEL         205        EMA7
#
# ======================================================================
# 🔹 BLOQUE: BIOBLO2 | PROGRAMA EDUCATIVO: BIO
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        08:00 - 09:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         303        EMA5
# Lunes        08:00 - 09:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  305        EMA6
# Lunes        10:00 - 12:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   307        EMA5
# Lunes        11:00 - 12:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         303        EMA5
# Lunes        14:00 - 15:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         303        EMA5
# Martes       11:00 - 12:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         303        EMA5
# Martes       11:00 - 13:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  305        EMA6
# Martes       17:00 - 18:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         303        EMA5
# Miércoles    09:00 - 10:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   307        EMA5
# Miércoles    11:00 - 12:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  305        EMA6
# Miércoles    15:00 - 16:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  305        EMA6
# Miércoles    16:00 - 17:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   307        EMA5
# Viernes      08:00 - 09:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  305        EMA6
# Viernes      10:00 - 11:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   307        EMA5
# Viernes      10:00 - 11:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         303        EMA5
# Viernes      14:00 - 15:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  305        EMA6
# Viernes      15:00 - 16:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         303        EMA5
#
# ======================================================================
# 🔹 BLOQUE: BIOBLO3 | PROGRAMA EDUCATIVO: BIO
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        08:00 - 09:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   102        EMA5
# Martes       08:00 - 10:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  106        EMA6
# Martes       10:00 - 11:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         103        EMA5
# Martes       15:00 - 16:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  106        EMA6
# Miércoles    10:00 - 11:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         103        EMA5
# Miércoles    11:00 - 12:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   102        EMA5
# Miércoles    13:00 - 15:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  106        EMA6
# Miércoles    14:00 - 15:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         103        EMA5
# Miércoles    17:00 - 18:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         103        EMA5
# Jueves       08:00 - 10:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         103        EMA5
# Jueves       10:00 - 11:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  106        EMA6
# Jueves       11:00 - 12:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   102        EMA5
# Viernes      08:00 - 09:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         103        EMA5
# Viernes      09:00 - 10:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   102        EMA5
# Viernes      12:00 - 13:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   102        EMA5
# Viernes      17:00 - 18:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  106        EMA6
#
# ======================================================================
# 🔹 BLOQUE: BIOBLO4 | PROGRAMA EDUCATIVO: BIO
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        13:00 - 14:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  204        EMA6
# Lunes        15:00 - 16:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  204        EMA6
# Martes       10:00 - 11:00   Biomatematicas I                    REYES - ROMERO MARIBEL         203        EMA7
# Martes       13:00 - 14:00   Biomatematicas I                    REYES - ROMERO MARIBEL         203        EMA7
# Martes       13:00 - 15:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   105        EMA7
# Miércoles    09:00 - 10:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  204        EMA6
# Miércoles    12:00 - 13:00   Biomatematicas I                    REYES - ROMERO MARIBEL         203        EMA7
# Miércoles    14:00 - 15:00   Biomatematicas I                    REYES - ROMERO MARIBEL         203        EMA7
# Miércoles    15:00 - 16:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   105        EMA7
# Miércoles    16:00 - 17:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  204        EMA6
# Miércoles    17:00 - 18:00   Biomatematicas I                    REYES - ROMERO MARIBEL         203        EMA7
# Jueves       08:00 - 09:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   105        EMA7
# Jueves       09:00 - 10:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  204        EMA6
# Jueves       16:00 - 17:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   105        EMA7
# Viernes      09:00 - 10:00   Biomatematicas I                    REYES - ROMERO MARIBEL         203        EMA7
# Viernes      15:00 - 16:00   Biomatematicas I                    REYES - ROMERO MARIBEL         203        EMA7
# Viernes      15:00 - 17:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  204        EMA6
#
# ======================================================================
# 🔹 BLOQUE: BIOBLO5 | PROGRAMA EDUCATIVO: BIO
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        12:00 - 14:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   108        EMA7
# Lunes        17:00 - 18:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   108        EMA7
# Martes       08:00 - 09:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         107        EMA7
# Martes       11:00 - 13:00   Quimica General                     DE ANDA - REYES MARIA EUNICE   205        EMA7
# Martes       13:00 - 14:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         107        EMA7
# Martes       15:00 - 16:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         107        EMA7
# Martes       17:00 - 18:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   108        EMA7
# Miércoles    08:00 - 09:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         107        EMA7
# Miércoles    11:00 - 12:00   Quimica General                     DE ANDA - REYES MARIA EUNICE   205        EMA7
# Miércoles    12:00 - 13:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   108        EMA7
# Miércoles    16:00 - 17:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         107        EMA7
# Jueves       14:00 - 15:00   Quimica General                     DE ANDA - REYES MARIA EUNICE   205        EMA7
# Jueves       15:00 - 16:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         107        EMA7
# Jueves       17:00 - 18:00   Quimica General                     DE ANDA - REYES MARIA EUNICE   205        EMA7
# Viernes      09:00 - 10:00   Quimica General                     DE ANDA - REYES MARIA EUNICE   205        EMA7
# Viernes      12:00 - 13:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         107        EMA7
# Viernes      15:00 - 16:00   Quimica General                     DE ANDA - REYES MARIA EUNICE   205        EMA7
#
# ======================================================================
# 🔹 BLOQUE: BIOBLO6 | PROGRAMA EDUCATIVO: BIO
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        09:00 - 10:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         301        EMA6
# Lunes        11:00 - 12:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  306        EMA5
# Lunes        15:00 - 16:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   307        EMA7
# Lunes        15:00 - 16:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         301        EMA6
# Lunes        16:00 - 17:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  306        EMA5
# Martes       12:00 - 13:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         301        EMA6
# Martes       14:00 - 15:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         301        EMA6
# Martes       14:00 - 15:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  306        EMA5
# Martes       17:00 - 18:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  306        EMA5
# Miércoles    09:00 - 10:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         301        EMA6
# Jueves       08:00 - 09:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  306        EMA5
# Jueves       10:00 - 11:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   307        EMA7
# Jueves       11:00 - 12:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         301        EMA6
# Jueves       14:00 - 15:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  306        EMA5
# Jueves       14:00 - 16:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   307        EMA7
# Viernes      13:00 - 14:00   Introduccion a la Biologia          CONTRERAS - ALVARADO MINERVA   307        EMA7
# Viernes      13:00 - 14:00   Biomatematicas I                    DIAZ - DE ANDA ALFREDO         301        EMA6
# Viernes      13:00 - 14:00   Quimica General                     SANTIBAÑEZ - AGUASCALIENTES N  306        EMA5
#
# ======================================================================
# 🔹 BLOQUE: BIOBLO7 | PROGRAMA EDUCATIVO: BIO
# ======================================================================
# Día          Hora            Materia                             Profesor                       Aula       Edificio
# ----------------------------------------------------------------------------------------------------------------------------------
# Lunes        11:00 - 12:00   Quimica General                     CRUZ - MERIDA JORGE ALEJANDRO  209        EMA6
# Lunes        11:00 - 12:00   Biomatematicas I                    REYES - ROMERO MARIBEL         108        EMA7
# Lunes        16:00 - 17:00   Biomatematicas I                    REYES - ROMERO MARIBEL         108        EMA7
# Martes       08:00 - 10:00   Biomatematicas I                    REYES - ROMERO MARIBEL         108        EMA7
# Martes       10:00 - 11:00   Quimica General                     CRUZ - MERIDA JORGE ALEJANDRO  209        EMA6
# Martes       12:00 - 13:00   Introduccion a la Biologia          DIAZ - CARRANZA GUADALUPE      201        EMA7
# Martes       14:00 - 15:00   Quimica General                     CRUZ - MERIDA JORGE ALEJANDRO  209        EMA6
# Miércoles    08:00 - 09:00   Introduccion a la Biologia          DIAZ - CARRANZA GUADALUPE      201        EMA7
# Miércoles    10:00 - 11:00   Quimica General                     CRUZ - MERIDA JORGE ALEJANDRO  209        EMA6
# Miércoles    11:00 - 12:00   Biomatematicas I                    REYES - ROMERO MARIBEL         108        EMA7
# Miércoles    14:00 - 15:00   Introduccion a la Biologia          DIAZ - CARRANZA GUADALUPE      201        EMA7
# Miércoles    14:00 - 15:00   Quimica General                     CRUZ - MERIDA JORGE ALEJANDRO  209        EMA6
# Miércoles    16:00 - 17:00   Quimica General                     CRUZ - MERIDA JORGE ALEJANDRO  209        EMA6
# Miércoles    16:00 - 17:00   Biomatematicas I                    REYES - ROMERO MARIBEL         108        EMA7
# Jueves       09:00 - 10:00   Introduccion a la Biologia          DIAZ - CARRANZA GUADALUPE      201        EMA7
# Jueves       16:00 - 17:00   Introduccion a la Biologia          DIAZ - CARRANZA GUADALUPE      201        EMA7
# Jueves       17:00 - 18:00   Biomatematicas I                    REYES - ROMERO MARIBEL         108        EMA7
# Viernes      10:00 - 11:00   Quimica General                     CRUZ - MERIDA JORGE ALEJANDRO  209        EMA6
#
# 📁 Archivo 'horarios_por_bloque.xlsx' creado con éxito.
#
#
# Profesores asignados: 26 de 392
# ✅ No hay solapamientos de profesor.
# ✅ No hay solapamientos de aula.

# %%
import re

def revisar_restricciones(df):
    errores = []

    # ⚠️ Expandir horarios múltiples en filas individuales
    df_exp = df.copy()
    df_exp['Horario'] = df_exp['Horarios'].str.split('; ')
    df_exp = df_exp.explode('Horario')

    # Asegurar que 'Día' exista
    df_exp['Día'] = df_exp['Horario'].apply(lambda h: h.split()[0] if isinstance(h, str) else None)

    # Extraer hora de inicio
    def extraer_hora_inicio(horario):
        match = re.search(r'(\d{2}):\d{2}', horario)
        return int(match.group(1)) if match else None

    df_exp['Hora_inicio'] = df_exp['Horario'].apply(extraer_hora_inicio)

    # Clave principal para agrupación
    clave_materia = ['id_materia', 'Programa_Educativo']

    # 1. Materias sin profesor
    sin_profe = df_exp[df_exp['Profesor'].isnull()][clave_materia].drop_duplicates()
    if not sin_profe.empty:
        errores.append(f"Materias sin profesor asignado:\n{sin_profe.to_dict(orient='records')}")

    # 2. Materias con menos de 1 horario
    horas_por_materia = df_exp.groupby(clave_materia)['Horario'].nunique()
    pocas_horas = horas_por_materia[horas_por_materia < 1]
    if not pocas_horas.empty:
        errores.append(f"Materias con menos horas semanales:\n{pocas_horas.index.tolist()}")

    # 3. Materias en múltiples aulas
    aulas_por_materia = df_exp.groupby(clave_materia)['Aula'].nunique()
    multiples_aulas = aulas_por_materia[aulas_por_materia > 1]
    if not multiples_aulas.empty:
        errores.append(f"Materias en múltiples aulas:\n{multiples_aulas.index.tolist()}")

    # 4. Profesores con más de 10 horarios
    max_horas = 10
    horas_por_profesor = df_exp.groupby('Profesor')['Horario'].nunique()
    excedidos = horas_por_profesor[horas_por_profesor > max_horas]
    if not excedidos.empty:
        errores.append(f"Profesores con más de {max_horas} horarios:\n{excedidos.index.tolist()}")

    # 5. Materias en múltiples edificios
    edificios_por_materia = df_exp.groupby(clave_materia)['Edificio'].nunique()
    multiples_edificios = edificios_por_materia[edificios_por_materia > 1]
    if not multiples_edificios.empty:
        errores.append(f"Materias en múltiples edificios:\n{multiples_edificios.index.tolist()}")

    # 6. Materias con más de un profesor
    profes_por_materia = df_exp.groupby(clave_materia)['Profesor'].nunique()
    varios_profes = profes_por_materia[profes_por_materia > 1]
    if not varios_profes.empty:
        errores.append(f"Materias con más de un profesor asignado:\n{varios_profes.index.tolist()}")

    # 7. Profesores con clases simultáneas
    profe_horario = df_exp.groupby(['Profesor', 'Horario']).size()
    conflictos_profe = profe_horario[profe_horario > 1]
    if not conflictos_profe.empty:
        errores.append(f"Profesores con clases simultáneas:\n{conflictos_profe.index.tolist()}")

    # 8. Aulas con clases simultáneas
    aula_horario = df_exp.groupby(['Aula','Edificio','Horario']).size()
    conflictos_aula = aula_horario[aula_horario > 1]
    if not conflictos_aula.empty:
        errores.append(f"Aulas con clases simultáneas:\n{conflictos_aula.index.tolist()}")

    # 11. Clases no consecutivas por materia y día
    for (m_id, programa, dia), grupo in df_exp.groupby(clave_materia + ['Día']):
        horas = sorted(grupo['Hora_inicio'].dropna().unique())
        if len(horas) > 1:
            consecutivas = all(horas[i+1] == horas[i] + 1 for i in range(len(horas)-1))
            if not consecutivas:
                errores.append(f"Clases no consecutivas para materia {m_id} (Programa {programa}) el día {dia}: {horas}")

    # Resultados
    if errores:
        print("❌ Restricciones violadas:")
        for e in errores:
            print(f"- {e}")
    else:
        print("✅ Todas las restricciones se cumplen.")

# Ejecutar verificación
revisar_restricciones(df)
# Out:
# ❌ Restricciones violadas:
# - Materias en múltiples aulas:
# [(1, 'ARQ'), (2, 'ARQ'), (3, 'ARQ'), (4, 'ARQ'), (5, 'ARQ'), (6, 'ARQ'), (7, 'ARQ'), (8, 'BIO'), (9, 'BIO'), (10, 'BIO')]
# - Profesores con más de 10 horarios:
# ['ALONSO - PEREZ CARLOS', 'CONTRERAS - ALVARADO MINERVA', 'DIAZ - DE ANDA ALFREDO', 'JAEN - VARGAS MARIA GUADALUPE', 'MALDONADO - CASTRO NAHELY', 'MALDONADO - SANCHEZ PABLO', 'MENDOZA - DIAZ LUIS FELIPE', 'MORA - RODRIGUEZ DAVID', 'MORALES - ORTEGA JOSE ALEJANDRO', 'REYES - ROMERO MARIBEL', 'ROSAS - LORANCA ROBERTO', 'SANTIBAÑEZ - AGUASCALIENTES NORMA ANGELICA', 'VAZQUEZ - GOMEZ NOEMI ZAHIRA', 'VERGARA - JUAREZ ENRIQUE', 'VIDAL - FLORES ANA MARIA DEL RAYO']
# - Materias en múltiples edificios:
# [(1, 'ARQ'), (2, 'ARQ'), (3, 'ARQ'), (4, 'ARQ'), (5, 'ARQ'), (6, 'ARQ'), (7, 'ARQ'), (8, 'BIO'), (9, 'BIO'), (10, 'BIO')]
# - Materias con más de un profesor asignado:
# [(1, 'ARQ'), (2, 'ARQ'), (3, 'ARQ'), (4, 'ARQ'), (5, 'ARQ'), (6, 'ARQ'), (7, 'ARQ'), (8, 'BIO'), (9, 'BIO'), (10, 'BIO')]
# - Clases no consecutivas para materia 1 (Programa ARQ) el día Jueves: [10, 11, 13, 14, 15, 16]
# - Clases no consecutivas para materia 1 (Programa ARQ) el día Lunes: [10, 13, 15]
# - Clases no consecutivas para materia 1 (Programa ARQ) el día Martes: [8, 9, 14, 16, 17]
# - Clases no consecutivas para materia 1 (Programa ARQ) el día Miércoles: [8, 9, 11, 13, 15]
# - Clases no consecutivas para materia 1 (Programa ARQ) el día Viernes: [9, 14, 15, 16]
# - Clases no consecutivas para materia 2 (Programa ARQ) el día Jueves: [12, 15, 17]
# - Clases no consecutivas para materia 2 (Programa ARQ) el día Lunes: [8, 12, 15, 16, 17]
# - Clases no consecutivas para materia 2 (Programa ARQ) el día Martes: [12, 13, 14, 16, 17]
# - Clases no consecutivas para materia 2 (Programa ARQ) el día Miércoles: [9, 13, 14, 16]
# - Clases no consecutivas para materia 2 (Programa ARQ) el día Viernes: [8, 9, 11, 15, 17]
# - Clases no consecutivas para materia 3 (Programa ARQ) el día Jueves: [8, 9, 10, 11, 15]
# - Clases no consecutivas para materia 3 (Programa ARQ) el día Lunes: [8, 11, 12, 15, 16]
# - Clases no consecutivas para materia 3 (Programa ARQ) el día Martes: [8, 13, 14]
# - Clases no consecutivas para materia 3 (Programa ARQ) el día Miércoles: [9, 10, 11, 13, 15, 16, 17]
# - Clases no consecutivas para materia 3 (Programa ARQ) el día Viernes: [8, 10, 11, 14, 15, 17]
# - Clases no consecutivas para materia 4 (Programa ARQ) el día Jueves: [8, 9, 10, 11, 16, 17]
# - Clases no consecutivas para materia 4 (Programa ARQ) el día Lunes: [8, 9, 10, 11, 12, 13, 14, 16, 17]
# - Clases no consecutivas para materia 4 (Programa ARQ) el día Martes: [9, 10, 11, 12, 15]
# - Clases no consecutivas para materia 4 (Programa ARQ) el día Miércoles: [11, 12, 14]
# - Clases no consecutivas para materia 4 (Programa ARQ) el día Viernes: [8, 10, 12, 15, 16, 17]
# - Clases no consecutivas para materia 5 (Programa ARQ) el día Lunes: [9, 11, 13, 14, 16, 17]
# - Clases no consecutivas para materia 5 (Programa ARQ) el día Martes: [8, 9, 10, 11, 12, 14, 15, 16]
# - Clases no consecutivas para materia 5 (Programa ARQ) el día Miércoles: [8, 9, 12, 13, 15, 16]
# - Clases no consecutivas para materia 5 (Programa ARQ) el día Viernes: [8, 9, 12, 13, 14, 16]
# - Clases no consecutivas para materia 6 (Programa ARQ) el día Jueves: [8, 11, 12, 13, 15, 16]
# - Clases no consecutivas para materia 6 (Programa ARQ) el día Lunes: [8, 9, 10, 11, 13, 14, 15, 16, 17]
# - Clases no consecutivas para materia 6 (Programa ARQ) el día Martes: [8, 10, 12, 13, 14, 15, 17]
# - Clases no consecutivas para materia 6 (Programa ARQ) el día Miércoles: [8, 10, 11, 12, 14, 15, 17]
# - Clases no consecutivas para materia 6 (Programa ARQ) el día Viernes: [8, 9, 11, 12, 13, 15, 16, 17]
# - Clases no consecutivas para materia 7 (Programa ARQ) el día Jueves: [8, 11, 12, 13, 15, 16, 17]
# - Clases no consecutivas para materia 7 (Programa ARQ) el día Lunes: [8, 11, 12, 14, 15, 17]
# - Clases no consecutivas para materia 7 (Programa ARQ) el día Martes: [8, 10, 13, 15, 16, 17]
# - Clases no consecutivas para materia 7 (Programa ARQ) el día Miércoles: [8, 9, 10, 15, 17]
# - Clases no consecutivas para materia 7 (Programa ARQ) el día Viernes: [9, 10, 11, 13, 17]
# - Clases no consecutivas para materia 8 (Programa BIO) el día Jueves: [8, 9, 10, 11, 13, 14, 16]
# - Clases no consecutivas para materia 8 (Programa BIO) el día Lunes: [8, 9, 10, 11, 12, 15, 17]
# - Clases no consecutivas para materia 8 (Programa BIO) el día Martes: [12, 13, 17]
# - Clases no consecutivas para materia 8 (Programa BIO) el día Miércoles: [8, 9, 11, 12, 14, 15, 16]
# - Clases no consecutivas para materia 8 (Programa BIO) el día Viernes: [9, 10, 12, 13]
# - Clases no consecutivas para materia 9 (Programa BIO) el día Jueves: [8, 11, 13, 15, 17]
# - Clases no consecutivas para materia 9 (Programa BIO) el día Lunes: [8, 9, 10, 11, 13, 14, 15, 16]
# - Clases no consecutivas para materia 9 (Programa BIO) el día Martes: [8, 10, 11, 12, 13, 14, 15, 16, 17]
# - Clases no consecutivas para materia 9 (Programa BIO) el día Miércoles: [8, 9, 10, 11, 12, 14, 16, 17]
# - Clases no consecutivas para materia 9 (Programa BIO) el día Viernes: [8, 9, 10, 12, 13, 14, 15]
# - Clases no consecutivas para materia 10 (Programa BIO) el día Jueves: [8, 9, 10, 13, 14, 15, 17]
# - Clases no consecutivas para materia 10 (Programa BIO) el día Lunes: [8, 9, 11, 13, 15, 16]
# - Clases no consecutivas para materia 10 (Programa BIO) el día Martes: [8, 10, 11, 14, 15, 16, 17]
# - Clases no consecutivas para materia 10 (Programa BIO) el día Miércoles: [9, 10, 11, 13, 14, 15, 16, 17]
# - Clases no consecutivas para materia 10 (Programa BIO) el día Viernes: [8, 9, 10, 13, 14, 15, 17]

# %%
# Verificar si materias del mismo bloque están sobrepuestas en horarios (aula y horario)
def materias_solapadas_en_bloque(df):
    # Expandir horarios múltiples en filas individuales
    df_exp = df.copy()
    df_exp['Horario'] = df_exp['Horarios'].str.split('; ')
    df_exp = df_exp.explode('Horario')

    # Agrupar por Bloque y Horario, contar materias distintas
    solapes = (
        df_exp.groupby(['Bloque', 'Horario'])
        .agg({'id_materia': 'nunique'})
        .reset_index()
    )
    # Filtrar donde hay más de una materia en el mismo bloque y horario
    solapes = solapes[solapes['id_materia'] > 1]

    if not solapes.empty:
        print("❌ Hay materias del mismo bloque sobrepuestas en el mismo horario:")
        print(solapes)
    else:
        print("✅ No hay materias del mismo bloque sobrepuestas en horarios.")

# Usar con el dataframe de asignaciones (df)
materias_solapadas_en_bloque(df)
# Out:
# ❌ Hay materias del mismo bloque sobrepuestas en el mismo horario:
#        Bloque                  Horario  id_materia
# 2     ARQBLO1     Jueves 16:00 - 17:00           2
# 3     ARQBLO1     Jueves 17:00 - 18:00           2
# 17    ARQBLO1    Viernes 11:00 - 12:00           2
# 20    ARQBLO1    Viernes 17:00 - 18:00           2
# 28   ARQBLO10     Martes 08:00 - 09:00           3
# 43    ARQBLO2     Jueves 11:00 - 12:00           2
# 45    ARQBLO2     Jueves 15:00 - 16:00           4
# 50    ARQBLO2      Lunes 16:00 - 17:00           2
# 52    ARQBLO2      Lunes 17:00 - 18:00           2
# 58    ARQBLO2  Miércoles 09:00 - 10:00           2
# 62    ARQBLO3     Jueves 08:00 - 09:00           3
# 70    ARQBLO3     Martes 13:00 - 14:00           3
# 73    ARQBLO3  Miércoles 09:00 - 10:00           2
# 81    ARQBLO4     Jueves 08:00 - 09:00           2
# 85    ARQBLO4     Jueves 16:00 - 17:00           2
# 91    ARQBLO4     Martes 14:00 - 15:00           2
# 92    ARQBLO4     Martes 17:00 - 18:00           2
# 95    ARQBLO4  Miércoles 13:00 - 14:00           2
# 101   ARQBLO4    Viernes 17:00 - 18:00           2
# 105   ARQBLO5      Lunes 08:00 - 09:00           3
# 106   ARQBLO5      Lunes 10:00 - 11:00           2
# 109   ARQBLO5     Martes 10:00 - 11:00           2
# 112   ARQBLO5  Miércoles 09:00 - 10:00           2
# 115   ARQBLO5  Miércoles 13:00 - 14:00           2
# 123   ARQBLO6     Jueves 15:00 - 16:00           2
# 127   ARQBLO6      Lunes 12:00 - 13:00           2
# 128   ARQBLO6      Lunes 15:00 - 16:00           2
# 129   ARQBLO6     Martes 08:00 - 09:00           2
# 136   ARQBLO6  Miércoles 14:00 - 15:00           2
# 140   ARQBLO6    Viernes 14:00 - 15:00           2
# 148   ARQBLO7      Lunes 12:00 - 13:00           2
# 151   ARQBLO7      Lunes 16:00 - 17:00           2
# 155   ARQBLO7     Martes 16:00 - 17:00           2
# 159   ARQBLO7    Viernes 08:00 - 09:00           2
# 160   ARQBLO7    Viernes 09:00 - 10:00           2
# 168   ARQBLO8      Lunes 11:00 - 12:00           2
# 169   ARQBLO8      Lunes 13:00 - 14:00           2
# 171   ARQBLO8      Lunes 17:00 - 18:00           2
# 179   ARQBLO8  Miércoles 15:00 - 16:00           2
# 181   ARQBLO8    Viernes 08:00 - 09:00           2
# 188   ARQBLO9     Jueves 13:00 - 14:00           2
# 199   ARQBLO9     Martes 16:00 - 17:00           2
# 206   ARQBLO9    Viernes 15:00 - 16:00           2
# 210   BIOBLO1     Jueves 13:00 - 14:00           3
# 212   BIOBLO1      Lunes 09:00 - 10:00           2
# 217   BIOBLO1     Martes 16:00 - 17:00           2
# 222   BIOBLO2      Lunes 08:00 - 09:00           2
# 234   BIOBLO2    Viernes 10:00 - 11:00           2
# 294   BIOBLO6      Lunes 15:00 - 16:00           2
# 297   BIOBLO6     Martes 14:00 - 15:00           2
# 300   BIOBLO6    Viernes 13:00 - 14:00           3
# 304   BIOBLO7      Lunes 11:00 - 12:00           2
# 313   BIOBLO7  Miércoles 14:00 - 15:00           2
# 314   BIOBLO7  Miércoles 16:00 - 17:00           2
